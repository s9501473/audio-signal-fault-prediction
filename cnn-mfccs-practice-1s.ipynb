# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import librosa
import os
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## 加載音頻訊號

# %%
data_path = '/kaggle/input/recoding-data/UAV Recordings 1s/UAV Recordings 1s'

# %% [markdown]
# ## 音頻訊號進行MFCCs特徵提取

# %%
def load_data(data_dir):
    datasets = []
    labels = []
    categories = os.listdir(data_dir)
    for index, folder in enumerate(categories):
        for filename in os.listdir(data_dir+"/"+folder):
            data, sampling_rate = librosa.load(data_dir+"/"+folder+"/"+filename)
            mfccs_features = librosa.feature.mfcc(y=data, sr=sampling_rate, n_mfcc=80)
            mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
            datasets.append(np.array(mfccs_scaled_features))
            labels.append(categories[index])
    return np.array(datasets), np.array(labels)

datasets, labels = load_data(data_path)

# %%
datasets = datasets.reshape(datasets.shape[0],datasets.shape[1], 1, 1).astype('float32')

labelencoder = LabelEncoder()

labelsOneHot = to_categorical(labelencoder.fit_transform(labels))

# %% [markdown]
# ## 切分成訓練資料、測試資料，8:2的比例

# %%
X_train, X_test, y_train, y_test = train_test_split(datasets, labelsOneHot, test_size = 0.2, stratify = labelsOneHot, random_state = 3)

print("----------Train-------------")
print(X_train.shape)

print("----------Test--------------")
print(X_test.shape)
# Out:
# ----------Train-------------
# (4512, 80, 1, 1)
# ----------Test--------------
# (1128, 80, 1, 1)

# %% [markdown]
# ## 類別數量

# %%
num_classes = len(np.unique(labels))

# %% [markdown]
# ## 建立CNN模型

# %%
# 建立一個Sequential模型
model = Sequential()

# 第一層卷積層，32個3x3的過濾器
model.add(Conv2D(32, kernel_size=(5, 5), padding='same',activation='relu', input_shape=(datasets.shape[1],1,1)))

# 池化層，池化窗口大小為2x2
model.add(MaxPooling2D(pool_size=(2,2), padding='same'))

# 第二層卷積層，128個3x3的過濾器
model.add(Conv2D(64, kernel_size=(5, 5), padding='same', activation='relu'))

# 池化層，池化窗口大小為2x2
model.add(MaxPooling2D(pool_size=(2,2), padding='same'))

# 第三層卷積層，256個3x3的過濾器
model.add(Conv2D(256, kernel_size=(5, 5), padding='same', activation='relu'))

# 池化層，池化窗口大小為2x2
model.add(MaxPooling2D(pool_size=(2,2), padding='same'))

# Dropout層，隨機丟棄25%的神經元
model.add(Dropout(0.25))

# Flatten層，將多維輸入一維化，常用在從卷積層到全連接層的過渡
model.add(Flatten())

# 全連接層，128個輸出單元
model.add(Dense(256, activation='relu'))

# 輸出層，有5個類別，所以輸出層的輸出維度為5
model.add(Dense(num_classes, activation='softmax'))

# %%
# 選擇損失函數、優化方法及成效衡量方式
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 80, 1, 32)         832
#
#  max_pooling2d (MaxPooling2  (None, 40, 1, 32)         0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 40, 1, 64)         51264
#
#  max_pooling2d_1 (MaxPoolin  (None, 20, 1, 64)         0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 20, 1, 256)        409856
#
#  max_pooling2d_2 (MaxPoolin  (None, 10, 1, 256)        0
#  g2D)
#
#  dropout (Dropout)           (None, 10, 1, 256)        0
#
#  flatten (Flatten)           (None, 2560)              0
#
#  dense (Dense)               (None, 256)               655616
#
#  dense_1 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 1118853 (4.27 MB)
# Trainable params: 1118853 (4.27 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 訓練模型

# %%
train_history = model.fit(X_train, y_train, validation_split=0.2, batch_size = 100, epochs = 100, verbose=2)
# Out:
# Epoch 1/100
# 37/37 - 6s - loss: 1.1916 - accuracy: 0.5109 - val_loss: 0.9023 - val_accuracy: 0.5781 - 6s/epoch - 154ms/step
# Epoch 2/100
# 37/37 - 4s - loss: 0.8240 - accuracy: 0.6628 - val_loss: 0.7730 - val_accuracy: 0.7110 - 4s/epoch - 108ms/step
# Epoch 3/100
# 37/37 - 4s - loss: 0.7190 - accuracy: 0.7188 - val_loss: 0.6563 - val_accuracy: 0.7486 - 4s/epoch - 108ms/step
# Epoch 4/100
# 37/37 - 4s - loss: 0.6018 - accuracy: 0.7697 - val_loss: 0.7396 - val_accuracy: 0.7054 - 4s/epoch - 110ms/step
# Epoch 5/100
# 37/37 - 4s - loss: 0.5411 - accuracy: 0.8013 - val_loss: 0.7881 - val_accuracy: 0.7121 - 4s/epoch - 120ms/step
# Epoch 6/100
# 37/37 - 4s - loss: 0.5252 - accuracy: 0.8119 - val_loss: 0.4805 - val_accuracy: 0.8206 - 4s/epoch - 109ms/step
# Epoch 7/100
# 37/37 - 4s - loss: 0.4693 - accuracy: 0.8252 - val_loss: 0.4445 - val_accuracy: 0.8383 - 4s/epoch - 110ms/step
# Epoch 8/100
# 37/37 - 4s - loss: 0.3874 - accuracy: 0.8640 - val_loss: 0.4094 - val_accuracy: 0.8416 - 4s/epoch - 111ms/step
# Epoch 9/100
# 37/37 - 4s - loss: 0.3693 - accuracy: 0.8689 - val_loss: 0.3617 - val_accuracy: 0.8627 - 4s/epoch - 109ms/step
# Epoch 10/100
# 37/37 - 4s - loss: 0.3323 - accuracy: 0.8809 - val_loss: 0.3727 - val_accuracy: 0.8583 - 4s/epoch - 110ms/step
# Epoch 11/100
# 37/37 - 4s - loss: 0.2727 - accuracy: 0.9044 - val_loss: 0.3938 - val_accuracy: 0.8516 - 4s/epoch - 110ms/step
# Epoch 12/100
# 37/37 - 4s - loss: 0.2605 - accuracy: 0.9027 - val_loss: 0.3457 - val_accuracy: 0.8715 - 4s/epoch - 111ms/step
# Epoch 13/100
# 37/37 - 5s - loss: 0.2653 - accuracy: 0.9011 - val_loss: 0.3226 - val_accuracy: 0.8782 - 5s/epoch - 122ms/step
# Epoch 14/100
# 37/37 - 4s - loss: 0.2340 - accuracy: 0.9135 - val_loss: 0.2782 - val_accuracy: 0.8959 - 4s/epoch - 109ms/step
# Epoch 15/100
# 37/37 - 4s - loss: 0.1948 - accuracy: 0.9324 - val_loss: 0.2829 - val_accuracy: 0.8904 - 4s/epoch - 110ms/step
# Epoch 16/100
# 37/37 - 4s - loss: 0.1707 - accuracy: 0.9385 - val_loss: 0.2633 - val_accuracy: 0.9037 - 4s/epoch - 111ms/step
# Epoch 17/100
# 37/37 - 4s - loss: 0.1642 - accuracy: 0.9424 - val_loss: 0.2621 - val_accuracy: 0.8893 - 4s/epoch - 111ms/step
# Epoch 18/100
# 37/37 - 4s - loss: 0.1495 - accuracy: 0.9435 - val_loss: 0.2121 - val_accuracy: 0.9225 - 4s/epoch - 110ms/step
# Epoch 19/100
# 37/37 - 4s - loss: 0.1297 - accuracy: 0.9554 - val_loss: 0.2232 - val_accuracy: 0.9192 - 4s/epoch - 109ms/step
# Epoch 20/100
# 37/37 - 4s - loss: 0.1057 - accuracy: 0.9634 - val_loss: 0.3521 - val_accuracy: 0.8804 - 4s/epoch - 108ms/step
# Epoch 21/100
# 37/37 - 5s - loss: 0.2284 - accuracy: 0.9210 - val_loss: 0.2152 - val_accuracy: 0.9181 - 5s/epoch - 122ms/step
# Epoch 22/100
# 37/37 - 4s - loss: 0.1031 - accuracy: 0.9643 - val_loss: 0.2052 - val_accuracy: 0.9269 - 4s/epoch - 109ms/step
# Epoch 23/100
# 37/37 - 4s - loss: 0.0845 - accuracy: 0.9698 - val_loss: 0.2096 - val_accuracy: 0.9258 - 4s/epoch - 110ms/step
# Epoch 24/100
# 37/37 - 4s - loss: 0.0785 - accuracy: 0.9734 - val_loss: 0.2087 - val_accuracy: 0.9225 - 4s/epoch - 108ms/step
# Epoch 25/100
# 37/37 - 4s - loss: 0.0741 - accuracy: 0.9742 - val_loss: 0.3407 - val_accuracy: 0.8848 - 4s/epoch - 108ms/step
# Epoch 26/100
# 37/37 - 4s - loss: 0.0952 - accuracy: 0.9637 - val_loss: 0.1985 - val_accuracy: 0.9302 - 4s/epoch - 111ms/step
# Epoch 27/100
# 37/37 - 4s - loss: 0.0627 - accuracy: 0.9795 - val_loss: 0.1946 - val_accuracy: 0.9280 - 4s/epoch - 109ms/step
# Epoch 28/100
# 37/37 - 4s - loss: 0.0445 - accuracy: 0.9878 - val_loss: 0.2261 - val_accuracy: 0.9236 - 4s/epoch - 113ms/step
# Epoch 29/100
# 37/37 - 4s - loss: 0.0487 - accuracy: 0.9823 - val_loss: 0.1759 - val_accuracy: 0.9358 - 4s/epoch - 118ms/step
# Epoch 30/100
# 37/37 - 4s - loss: 0.0447 - accuracy: 0.9845 - val_loss: 0.2560 - val_accuracy: 0.9169 - 4s/epoch - 110ms/step
# Epoch 31/100
# 37/37 - 4s - loss: 0.0519 - accuracy: 0.9820 - val_loss: 0.1908 - val_accuracy: 0.9336 - 4s/epoch - 109ms/step
# Epoch 32/100
# 37/37 - 4s - loss: 0.0300 - accuracy: 0.9922 - val_loss: 0.2341 - val_accuracy: 0.9291 - 4s/epoch - 110ms/step
# Epoch 33/100
# 37/37 - 4s - loss: 0.0634 - accuracy: 0.9781 - val_loss: 0.2039 - val_accuracy: 0.9324 - 4s/epoch - 110ms/step
# Epoch 34/100
# 37/37 - 4s - loss: 0.0359 - accuracy: 0.9881 - val_loss: 0.2079 - val_accuracy: 0.9336 - 4s/epoch - 110ms/step
# Epoch 35/100
# 37/37 - 4s - loss: 0.0720 - accuracy: 0.9753 - val_loss: 0.1996 - val_accuracy: 0.9313 - 4s/epoch - 111ms/step
# Epoch 36/100
# 37/37 - 4s - loss: 0.0353 - accuracy: 0.9909 - val_loss: 0.2228 - val_accuracy: 0.9302 - 4s/epoch - 120ms/step
# Epoch 37/100
# 37/37 - 4s - loss: 0.0214 - accuracy: 0.9936 - val_loss: 0.2203 - val_accuracy: 0.9225 - 4s/epoch - 111ms/step
# Epoch 38/100
# 37/37 - 4s - loss: 0.0412 - accuracy: 0.9870 - val_loss: 0.2728 - val_accuracy: 0.9025 - 4s/epoch - 110ms/step
# Epoch 39/100
# 37/37 - 4s - loss: 0.0296 - accuracy: 0.9895 - val_loss: 0.2793 - val_accuracy: 0.9258 - 4s/epoch - 110ms/step
# Epoch 40/100
# 37/37 - 4s - loss: 0.0232 - accuracy: 0.9925 - val_loss: 0.2188 - val_accuracy: 0.9313 - 4s/epoch - 111ms/step
# Epoch 41/100
# 37/37 - 4s - loss: 0.0123 - accuracy: 0.9972 - val_loss: 0.2111 - val_accuracy: 0.9391 - 4s/epoch - 110ms/step
# Epoch 42/100
# 37/37 - 4s - loss: 0.0152 - accuracy: 0.9947 - val_loss: 0.2282 - val_accuracy: 0.9369 - 4s/epoch - 110ms/step
# Epoch 43/100
# 37/37 - 4s - loss: 0.0141 - accuracy: 0.9970 - val_loss: 0.2202 - val_accuracy: 0.9391 - 4s/epoch - 111ms/step
# Epoch 44/100
# 37/37 - 5s - loss: 0.0116 - accuracy: 0.9978 - val_loss: 0.2269 - val_accuracy: 0.9369 - 5s/epoch - 122ms/step
# Epoch 45/100
# 37/37 - 4s - loss: 0.0080 - accuracy: 0.9994 - val_loss: 0.2429 - val_accuracy: 0.9302 - 4s/epoch - 112ms/step
# Epoch 46/100
# 37/37 - 4s - loss: 0.0082 - accuracy: 0.9983 - val_loss: 0.2158 - val_accuracy: 0.9391 - 4s/epoch - 110ms/step
# Epoch 47/100
# 37/37 - 4s - loss: 0.0110 - accuracy: 0.9964 - val_loss: 0.2851 - val_accuracy: 0.9203 - 4s/epoch - 111ms/step
# Epoch 48/100
# 37/37 - 4s - loss: 0.0115 - accuracy: 0.9967 - val_loss: 0.2323 - val_accuracy: 0.9413 - 4s/epoch - 110ms/step
# Epoch 49/100
# 37/37 - 4s - loss: 0.0183 - accuracy: 0.9931 - val_loss: 0.2719 - val_accuracy: 0.9258 - 4s/epoch - 110ms/step
# Epoch 50/100
# 37/37 - 4s - loss: 0.1230 - accuracy: 0.9568 - val_loss: 0.2607 - val_accuracy: 0.9103 - 4s/epoch - 112ms/step
# Epoch 51/100
# 37/37 - 4s - loss: 0.0519 - accuracy: 0.9817 - val_loss: 0.2137 - val_accuracy: 0.9225 - 4s/epoch - 109ms/step
# Epoch 52/100
# 37/37 - 5s - loss: 0.0316 - accuracy: 0.9897 - val_loss: 0.2036 - val_accuracy: 0.9391 - 5s/epoch - 123ms/step
# Epoch 53/100
# 37/37 - 4s - loss: 0.0237 - accuracy: 0.9920 - val_loss: 0.2326 - val_accuracy: 0.9324 - 4s/epoch - 110ms/step
# Epoch 54/100
# 37/37 - 4s - loss: 0.0135 - accuracy: 0.9958 - val_loss: 0.2242 - val_accuracy: 0.9336 - 4s/epoch - 109ms/step
# Epoch 55/100
# 37/37 - 4s - loss: 0.0093 - accuracy: 0.9972 - val_loss: 0.2537 - val_accuracy: 0.9313 - 4s/epoch - 111ms/step
# Epoch 56/100
# 37/37 - 4s - loss: 0.0109 - accuracy: 0.9972 - val_loss: 0.2591 - val_accuracy: 0.9302 - 4s/epoch - 109ms/step
# Epoch 57/100
# 37/37 - 4s - loss: 0.0122 - accuracy: 0.9970 - val_loss: 0.2337 - val_accuracy: 0.9402 - 4s/epoch - 110ms/step
# Epoch 58/100
# 37/37 - 4s - loss: 0.0130 - accuracy: 0.9964 - val_loss: 0.2597 - val_accuracy: 0.9258 - 4s/epoch - 110ms/step
# Epoch 59/100
# 37/37 - 4s - loss: 0.0091 - accuracy: 0.9983 - val_loss: 0.2370 - val_accuracy: 0.9336 - 4s/epoch - 120ms/step
# Epoch 60/100
# 37/37 - 4s - loss: 0.0114 - accuracy: 0.9964 - val_loss: 0.2520 - val_accuracy: 0.9380 - 4s/epoch - 116ms/step
# Epoch 61/100
# 37/37 - 4s - loss: 0.0096 - accuracy: 0.9964 - val_loss: 0.2378 - val_accuracy: 0.9313 - 4s/epoch - 111ms/step
# Epoch 62/100
# 37/37 - 4s - loss: 0.0117 - accuracy: 0.9964 - val_loss: 0.2250 - val_accuracy: 0.9457 - 4s/epoch - 114ms/step
# Epoch 63/100
# 37/37 - 4s - loss: 0.0332 - accuracy: 0.9897 - val_loss: 0.2980 - val_accuracy: 0.9169 - 4s/epoch - 111ms/step
# Epoch 64/100
# 37/37 - 4s - loss: 0.0733 - accuracy: 0.9726 - val_loss: 0.2466 - val_accuracy: 0.9258 - 4s/epoch - 111ms/step
# Epoch 65/100
# 37/37 - 4s - loss: 0.0249 - accuracy: 0.9936 - val_loss: 0.1804 - val_accuracy: 0.9424 - 4s/epoch - 110ms/step
# Epoch 66/100
# 37/37 - 4s - loss: 0.0096 - accuracy: 0.9975 - val_loss: 0.2901 - val_accuracy: 0.9291 - 4s/epoch - 110ms/step
# Epoch 67/100
# 37/37 - 5s - loss: 0.0145 - accuracy: 0.9956 - val_loss: 0.2654 - val_accuracy: 0.9347 - 5s/epoch - 126ms/step
# Epoch 68/100
# 37/37 - 4s - loss: 0.0109 - accuracy: 0.9967 - val_loss: 0.2486 - val_accuracy: 0.9269 - 4s/epoch - 112ms/step
# Epoch 69/100
# 37/37 - 4s - loss: 0.0113 - accuracy: 0.9953 - val_loss: 0.2471 - val_accuracy: 0.9380 - 4s/epoch - 113ms/step
# Epoch 70/100
# 37/37 - 4s - loss: 0.0127 - accuracy: 0.9950 - val_loss: 0.2455 - val_accuracy: 0.9347 - 4s/epoch - 112ms/step
# Epoch 71/100
# 37/37 - 4s - loss: 0.0185 - accuracy: 0.9920 - val_loss: 0.2575 - val_accuracy: 0.9358 - 4s/epoch - 111ms/step
# Epoch 72/100
# 37/37 - 4s - loss: 0.0154 - accuracy: 0.9956 - val_loss: 0.2558 - val_accuracy: 0.9336 - 4s/epoch - 110ms/step
# Epoch 73/100
# 37/37 - 4s - loss: 0.0150 - accuracy: 0.9945 - val_loss: 0.3118 - val_accuracy: 0.9103 - 4s/epoch - 111ms/step
# Epoch 74/100
# 37/37 - 4s - loss: 0.0168 - accuracy: 0.9933 - val_loss: 0.2311 - val_accuracy: 0.9347 - 4s/epoch - 111ms/step
# Epoch 75/100
# 37/37 - 5s - loss: 0.0116 - accuracy: 0.9967 - val_loss: 0.2358 - val_accuracy: 0.9369 - 5s/epoch - 123ms/step
# Epoch 76/100
# 37/37 - 4s - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.2387 - val_accuracy: 0.9402 - 4s/epoch - 111ms/step
# Epoch 77/100
# 37/37 - 4s - loss: 0.0082 - accuracy: 0.9964 - val_loss: 0.3603 - val_accuracy: 0.9203 - 4s/epoch - 111ms/step
# Epoch 78/100
# 37/37 - 4s - loss: 0.0093 - accuracy: 0.9967 - val_loss: 0.2849 - val_accuracy: 0.9369 - 4s/epoch - 109ms/step
# Epoch 79/100
# 37/37 - 4s - loss: 0.0118 - accuracy: 0.9964 - val_loss: 0.2952 - val_accuracy: 0.9247 - 4s/epoch - 110ms/step
# Epoch 80/100
# 37/37 - 4s - loss: 0.0100 - accuracy: 0.9970 - val_loss: 0.2971 - val_accuracy: 0.9302 - 4s/epoch - 111ms/step
# Epoch 81/100
# 37/37 - 4s - loss: 0.0186 - accuracy: 0.9925 - val_loss: 0.3081 - val_accuracy: 0.9214 - 4s/epoch - 111ms/step
# Epoch 82/100
# 37/37 - 4s - loss: 0.0124 - accuracy: 0.9958 - val_loss: 0.2711 - val_accuracy: 0.9313 - 4s/epoch - 110ms/step
# Epoch 83/100
# 37/37 - 4s - loss: 0.0182 - accuracy: 0.9945 - val_loss: 0.3168 - val_accuracy: 0.9214 - 4s/epoch - 119ms/step
# Epoch 84/100
# 37/37 - 4s - loss: 0.0234 - accuracy: 0.9928 - val_loss: 0.3224 - val_accuracy: 0.9313 - 4s/epoch - 109ms/step
# Epoch 85/100
# 37/37 - 4s - loss: 0.0689 - accuracy: 0.9800 - val_loss: 0.3469 - val_accuracy: 0.8981 - 4s/epoch - 109ms/step
# Epoch 86/100
# 37/37 - 4s - loss: 0.0313 - accuracy: 0.9897 - val_loss: 0.3026 - val_accuracy: 0.9192 - 4s/epoch - 110ms/step
# Epoch 87/100
# 37/37 - 4s - loss: 0.0126 - accuracy: 0.9958 - val_loss: 0.2728 - val_accuracy: 0.9380 - 4s/epoch - 109ms/step
# Epoch 88/100
# 37/37 - 4s - loss: 0.0151 - accuracy: 0.9945 - val_loss: 0.3466 - val_accuracy: 0.9280 - 4s/epoch - 112ms/step
# Epoch 89/100
# 37/37 - 4s - loss: 0.0191 - accuracy: 0.9936 - val_loss: 0.3658 - val_accuracy: 0.9225 - 4s/epoch - 112ms/step
# Epoch 90/100
# 37/37 - 4s - loss: 0.0200 - accuracy: 0.9925 - val_loss: 0.3124 - val_accuracy: 0.9181 - 4s/epoch - 121ms/step
# Epoch 91/100
# 37/37 - 4s - loss: 0.0183 - accuracy: 0.9945 - val_loss: 0.2615 - val_accuracy: 0.9313 - 4s/epoch - 111ms/step
# Epoch 92/100
# 37/37 - 4s - loss: 0.0099 - accuracy: 0.9958 - val_loss: 0.2526 - val_accuracy: 0.9347 - 4s/epoch - 109ms/step
# Epoch 93/100
# 37/37 - 4s - loss: 0.0185 - accuracy: 0.9933 - val_loss: 0.2792 - val_accuracy: 0.9302 - 4s/epoch - 110ms/step
# Epoch 94/100
# 37/37 - 4s - loss: 0.0151 - accuracy: 0.9956 - val_loss: 0.3062 - val_accuracy: 0.9269 - 4s/epoch - 108ms/step
# Epoch 95/100
# 37/37 - 4s - loss: 0.0083 - accuracy: 0.9967 - val_loss: 0.2854 - val_accuracy: 0.9302 - 4s/epoch - 108ms/step
# Epoch 96/100
# 37/37 - 4s - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.2582 - val_accuracy: 0.9347 - 4s/epoch - 109ms/step
# Epoch 97/100
# 37/37 - 4s - loss: 0.0249 - accuracy: 0.9933 - val_loss: 0.2852 - val_accuracy: 0.9324 - 4s/epoch - 108ms/step
# Epoch 98/100
# 37/37 - 5s - loss: 0.0061 - accuracy: 0.9981 - val_loss: 0.2998 - val_accuracy: 0.9380 - 5s/epoch - 122ms/step
# Epoch 99/100
# 37/37 - 4s - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.2957 - val_accuracy: 0.9236 - 4s/epoch - 108ms/step
# Epoch 100/100
# 37/37 - 4s - loss: 0.0048 - accuracy: 0.9981 - val_loss: 0.2497 - val_accuracy: 0.9468 - 4s/epoch - 109ms/step

# %% [markdown]
# ## 評估訓練結果

# %%
def show_train_history(train_history, train, validation):

    plt.plot(train_history.history[train])

    plt.plot(train_history.history[validation])

    plt.title('Train History')

    plt.ylabel('train')

    plt.xlabel('Epoch')

    plt.legend(['train', 'validation'], loc='upper left')

    plt.show()
    

show_train_history(train_history, 'accuracy', 'val_accuracy')
show_train_history(train_history, 'loss', 'val_loss')

# %% [markdown]
# ## 使用未參與訓練的測試資料測試，模型準確率

# %%
scores = model.evaluate(X_test,y_test,verbose=0)

print('Accuracy = ', scores[1])
# Out:
# Accuracy =  0.9494680762290955

# %% [markdown]
# ## 評估訓練結果

# %%
y_pred = np.argmax(model.predict(X_test), axis=-1)
y_true = np.argmax(y_test, axis=-1)
confusion_matrix = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10,7))
sns.heatmap(confusion_matrix, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()
# Out:
# 36/36 [==============================] - 1s 10ms/step
