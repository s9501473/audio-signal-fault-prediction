# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import librosa
import os
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
# Out:
# 2024-01-31 08:15:21.506661: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-31 08:15:21.506810: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-31 08:15:21.677060: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ## 顯示音頻訊號圖

# %%
path = '/kaggle/input/recoding-data/UAV Recordings 1s/UAV Recordings 1s/Healthy/recording_2023-03-02_14-07-33_012.wav'

# 讀取音頻文件

plt.figure(figsize=(14,5))
data, sampling_rate = librosa.load(path)
librosa.display.waveshow(data,sr=sampling_rate)

# %% [markdown]
# ## 顯示MFCCs特徵圖

# %%
# 提取MFCCs特徵
mfccs_features = librosa.feature.mfcc(y = data, sr = sampling_rate, n_mfcc = 80)

# 繪製MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(mfccs_features, x_axis='time', sr=sampling_rate)
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 加載音頻訊號

# %%
data_path = '/kaggle/input/recoding-data/UAV Recordings 1s/UAV Recordings 1s'

# %% [markdown]
# ## 音頻訊號進行MFCCs特徵提取

# %%
def load_data(data_dir):
    datasets = []
    labels = []
    categories = os.listdir(data_dir)
    for index, folder in enumerate(categories):
        for filename in os.listdir(data_dir+"/"+folder):
            data, sampling_rate = librosa.load(data_dir+"/"+folder+"/"+filename)
            mfccs_features = librosa.feature.mfcc(y=data, sr=sampling_rate, n_mfcc=80)
            mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
            datasets.append(np.array(mfccs_scaled_features))
            labels.append(categories[index])
    return np.array(datasets), np.array(labels)

datasets, labels = load_data(data_path)

# %%
datasets = datasets.astype('float32')

labelencoder = LabelEncoder()

labelsOneHot = to_categorical(labelencoder.fit_transform(labels))

# %% [markdown]
# ## 切分成訓練資料、測試資料，8:2的比例

# %%
X_train, X_test, y_train, y_test = train_test_split(datasets, labelsOneHot, test_size = 0.2, stratify = labelsOneHot, random_state = 3)

print("----------Train-------------")
print(X_train.shape)

print("----------Test--------------")
print(X_test.shape)
# Out:
# ----------Train-------------
# (4512, 80)
# ----------Test--------------
# (1128, 80)

# %% [markdown]
# ## 類別數量

# %%
# declaring output layer unit

num_classes = len(np.unique(labels))

# %% [markdown]
# ## 建立NN模型

# %%
model=Sequential()

#Input layer
model.add(Flatten(input_shape=(80,)))

#hidden layer 1
model.add(Dense(512, Activation('relu')))

#hidden layer 2
model.add(Dense(128, Activation('relu')))

#hidden layer 3
model.add(Dense(64, Activation('relu')))

# 使用Dropout防止過度擬合
model.add(Dropout(0.25))

#Output layer
model.add(Dense(num_classes, Activation('softmax')))

# %%
# 選擇損失函數、優化方法及成效衡量方式
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 80)                0
#
#  dense (Dense)               (None, 512)               41472
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_3 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 115717 (452.02 KB)
# Trainable params: 115717 (452.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 模型訓練

# %%
train_history = model.fit(X_train, y_train, validation_split=0.2, batch_size = 100, epochs = 100, verbose=2)
# Out:
# Epoch 1/100
# 37/37 - 2s - loss: 1.4655 - accuracy: 0.5104 - val_loss: 0.8017 - val_accuracy: 0.6501 - 2s/epoch - 44ms/step
# Epoch 2/100
# 37/37 - 0s - loss: 0.7703 - accuracy: 0.7071 - val_loss: 0.5842 - val_accuracy: 0.7896 - 237ms/epoch - 6ms/step
# Epoch 3/100
# 37/37 - 0s - loss: 0.6022 - accuracy: 0.7725 - val_loss: 0.5210 - val_accuracy: 0.8018 - 223ms/epoch - 6ms/step
# Epoch 4/100
# 37/37 - 0s - loss: 0.5404 - accuracy: 0.7952 - val_loss: 0.4579 - val_accuracy: 0.8239 - 228ms/epoch - 6ms/step
# Epoch 5/100
# 37/37 - 0s - loss: 0.4399 - accuracy: 0.8357 - val_loss: 0.4705 - val_accuracy: 0.8217 - 223ms/epoch - 6ms/step
# Epoch 6/100
# 37/37 - 0s - loss: 0.4109 - accuracy: 0.8523 - val_loss: 0.3334 - val_accuracy: 0.8771 - 232ms/epoch - 6ms/step
# Epoch 7/100
# 37/37 - 0s - loss: 0.3794 - accuracy: 0.8664 - val_loss: 0.3353 - val_accuracy: 0.8671 - 252ms/epoch - 7ms/step
# Epoch 8/100
# 37/37 - 0s - loss: 0.3540 - accuracy: 0.8651 - val_loss: 0.3067 - val_accuracy: 0.8837 - 222ms/epoch - 6ms/step
# Epoch 9/100
# 37/37 - 0s - loss: 0.2938 - accuracy: 0.8964 - val_loss: 0.2780 - val_accuracy: 0.9014 - 256ms/epoch - 7ms/step
# Epoch 10/100
# 37/37 - 0s - loss: 0.2842 - accuracy: 0.8950 - val_loss: 0.3432 - val_accuracy: 0.8693 - 235ms/epoch - 6ms/step
# Epoch 11/100
# 37/37 - 0s - loss: 0.2737 - accuracy: 0.9005 - val_loss: 0.2819 - val_accuracy: 0.8926 - 221ms/epoch - 6ms/step
# Epoch 12/100
# 37/37 - 0s - loss: 0.2804 - accuracy: 0.8969 - val_loss: 0.3534 - val_accuracy: 0.8605 - 217ms/epoch - 6ms/step
# Epoch 13/100
# 37/37 - 0s - loss: 0.2415 - accuracy: 0.9077 - val_loss: 0.2183 - val_accuracy: 0.9158 - 235ms/epoch - 6ms/step
# Epoch 14/100
# 37/37 - 0s - loss: 0.2000 - accuracy: 0.9316 - val_loss: 0.2657 - val_accuracy: 0.9048 - 226ms/epoch - 6ms/step
# Epoch 15/100
# 37/37 - 0s - loss: 0.2127 - accuracy: 0.9274 - val_loss: 0.3221 - val_accuracy: 0.8793 - 214ms/epoch - 6ms/step
# Epoch 16/100
# 37/37 - 0s - loss: 0.2706 - accuracy: 0.9005 - val_loss: 0.2591 - val_accuracy: 0.8981 - 207ms/epoch - 6ms/step
# Epoch 17/100
# 37/37 - 0s - loss: 0.1845 - accuracy: 0.9341 - val_loss: 0.2112 - val_accuracy: 0.9214 - 212ms/epoch - 6ms/step
# Epoch 18/100
# 37/37 - 0s - loss: 0.1959 - accuracy: 0.9282 - val_loss: 0.2271 - val_accuracy: 0.9158 - 241ms/epoch - 7ms/step
# Epoch 19/100
# 37/37 - 0s - loss: 0.2057 - accuracy: 0.9219 - val_loss: 0.2198 - val_accuracy: 0.9192 - 261ms/epoch - 7ms/step
# Epoch 20/100
# 37/37 - 0s - loss: 0.1887 - accuracy: 0.9299 - val_loss: 0.2743 - val_accuracy: 0.9037 - 259ms/epoch - 7ms/step
# Epoch 21/100
# 37/37 - 0s - loss: 0.1707 - accuracy: 0.9382 - val_loss: 0.1749 - val_accuracy: 0.9347 - 211ms/epoch - 6ms/step
# Epoch 22/100
# 37/37 - 0s - loss: 0.1473 - accuracy: 0.9493 - val_loss: 0.1856 - val_accuracy: 0.9324 - 230ms/epoch - 6ms/step
# Epoch 23/100
# 37/37 - 0s - loss: 0.1402 - accuracy: 0.9534 - val_loss: 0.1856 - val_accuracy: 0.9291 - 251ms/epoch - 7ms/step
# Epoch 24/100
# 37/37 - 0s - loss: 0.1095 - accuracy: 0.9612 - val_loss: 0.1954 - val_accuracy: 0.9247 - 205ms/epoch - 6ms/step
# Epoch 25/100
# 37/37 - 0s - loss: 0.1217 - accuracy: 0.9537 - val_loss: 0.1809 - val_accuracy: 0.9358 - 210ms/epoch - 6ms/step
# Epoch 26/100
# 37/37 - 0s - loss: 0.1172 - accuracy: 0.9562 - val_loss: 0.2291 - val_accuracy: 0.9214 - 256ms/epoch - 7ms/step
# Epoch 27/100
# 37/37 - 0s - loss: 0.1092 - accuracy: 0.9634 - val_loss: 0.2077 - val_accuracy: 0.9247 - 226ms/epoch - 6ms/step
# Epoch 28/100
# 37/37 - 0s - loss: 0.1255 - accuracy: 0.9510 - val_loss: 0.1775 - val_accuracy: 0.9358 - 212ms/epoch - 6ms/step
# Epoch 29/100
# 37/37 - 0s - loss: 0.0863 - accuracy: 0.9723 - val_loss: 0.1659 - val_accuracy: 0.9391 - 215ms/epoch - 6ms/step
# Epoch 30/100
# 37/37 - 0s - loss: 0.0982 - accuracy: 0.9609 - val_loss: 0.2625 - val_accuracy: 0.9136 - 246ms/epoch - 7ms/step
# Epoch 31/100
# 37/37 - 0s - loss: 0.1061 - accuracy: 0.9623 - val_loss: 0.1654 - val_accuracy: 0.9468 - 244ms/epoch - 7ms/step
# Epoch 32/100
# 37/37 - 0s - loss: 0.0780 - accuracy: 0.9734 - val_loss: 0.2123 - val_accuracy: 0.9225 - 216ms/epoch - 6ms/step
# Epoch 33/100
# 37/37 - 0s - loss: 0.1436 - accuracy: 0.9487 - val_loss: 0.1763 - val_accuracy: 0.9358 - 219ms/epoch - 6ms/step
# Epoch 34/100
# 37/37 - 0s - loss: 0.0679 - accuracy: 0.9803 - val_loss: 0.2093 - val_accuracy: 0.9236 - 213ms/epoch - 6ms/step
# Epoch 35/100
# 37/37 - 0s - loss: 0.0693 - accuracy: 0.9770 - val_loss: 0.1816 - val_accuracy: 0.9380 - 216ms/epoch - 6ms/step
# Epoch 36/100
# 37/37 - 0s - loss: 0.0644 - accuracy: 0.9809 - val_loss: 0.1689 - val_accuracy: 0.9380 - 199ms/epoch - 5ms/step
# Epoch 37/100
# 37/37 - 0s - loss: 0.0797 - accuracy: 0.9734 - val_loss: 0.2324 - val_accuracy: 0.9225 - 254ms/epoch - 7ms/step
# Epoch 38/100
# 37/37 - 0s - loss: 0.0704 - accuracy: 0.9745 - val_loss: 0.2016 - val_accuracy: 0.9291 - 233ms/epoch - 6ms/step
# Epoch 39/100
# 37/37 - 0s - loss: 0.0595 - accuracy: 0.9789 - val_loss: 0.1624 - val_accuracy: 0.9480 - 203ms/epoch - 5ms/step
# Epoch 40/100
# 37/37 - 0s - loss: 0.0608 - accuracy: 0.9792 - val_loss: 0.1734 - val_accuracy: 0.9435 - 239ms/epoch - 6ms/step
# Epoch 41/100
# 37/37 - 0s - loss: 0.0992 - accuracy: 0.9648 - val_loss: 0.2637 - val_accuracy: 0.9236 - 213ms/epoch - 6ms/step
# Epoch 42/100
# 37/37 - 0s - loss: 0.0726 - accuracy: 0.9742 - val_loss: 0.1829 - val_accuracy: 0.9380 - 231ms/epoch - 6ms/step
# Epoch 43/100
# 37/37 - 0s - loss: 0.0539 - accuracy: 0.9825 - val_loss: 0.2021 - val_accuracy: 0.9236 - 217ms/epoch - 6ms/step
# Epoch 44/100
# 37/37 - 0s - loss: 0.0654 - accuracy: 0.9770 - val_loss: 0.2540 - val_accuracy: 0.9169 - 221ms/epoch - 6ms/step
# Epoch 45/100
# 37/37 - 0s - loss: 0.0950 - accuracy: 0.9651 - val_loss: 0.1790 - val_accuracy: 0.9391 - 223ms/epoch - 6ms/step
# Epoch 46/100
# 37/37 - 0s - loss: 0.0587 - accuracy: 0.9792 - val_loss: 0.2748 - val_accuracy: 0.9169 - 220ms/epoch - 6ms/step
# Epoch 47/100
# 37/37 - 0s - loss: 0.0514 - accuracy: 0.9817 - val_loss: 0.2497 - val_accuracy: 0.9269 - 211ms/epoch - 6ms/step
# Epoch 48/100
# 37/37 - 0s - loss: 0.0547 - accuracy: 0.9806 - val_loss: 0.2527 - val_accuracy: 0.9169 - 208ms/epoch - 6ms/step
# Epoch 49/100
# 37/37 - 0s - loss: 0.0551 - accuracy: 0.9784 - val_loss: 0.1733 - val_accuracy: 0.9513 - 251ms/epoch - 7ms/step
# Epoch 50/100
# 37/37 - 0s - loss: 0.0494 - accuracy: 0.9828 - val_loss: 0.2487 - val_accuracy: 0.9369 - 250ms/epoch - 7ms/step
# Epoch 51/100
# 37/37 - 0s - loss: 0.0471 - accuracy: 0.9834 - val_loss: 0.1833 - val_accuracy: 0.9468 - 201ms/epoch - 5ms/step
# Epoch 52/100
# 37/37 - 0s - loss: 0.0591 - accuracy: 0.9803 - val_loss: 0.1792 - val_accuracy: 0.9413 - 206ms/epoch - 6ms/step
# Epoch 53/100
# 37/37 - 0s - loss: 0.0580 - accuracy: 0.9798 - val_loss: 0.2169 - val_accuracy: 0.9391 - 205ms/epoch - 6ms/step
# Epoch 54/100
# 37/37 - 0s - loss: 0.0507 - accuracy: 0.9828 - val_loss: 0.1665 - val_accuracy: 0.9380 - 210ms/epoch - 6ms/step
# Epoch 55/100
# 37/37 - 0s - loss: 0.0345 - accuracy: 0.9889 - val_loss: 0.1744 - val_accuracy: 0.9435 - 209ms/epoch - 6ms/step
# Epoch 56/100
# 37/37 - 0s - loss: 0.0293 - accuracy: 0.9909 - val_loss: 0.1636 - val_accuracy: 0.9491 - 201ms/epoch - 5ms/step
# Epoch 57/100
# 37/37 - 0s - loss: 0.0381 - accuracy: 0.9881 - val_loss: 0.2340 - val_accuracy: 0.9402 - 203ms/epoch - 5ms/step
# Epoch 58/100
# 37/37 - 0s - loss: 0.0250 - accuracy: 0.9917 - val_loss: 0.2084 - val_accuracy: 0.9391 - 236ms/epoch - 6ms/step
# Epoch 59/100
# 37/37 - 0s - loss: 0.0188 - accuracy: 0.9958 - val_loss: 0.2063 - val_accuracy: 0.9457 - 217ms/epoch - 6ms/step
# Epoch 60/100
# 37/37 - 0s - loss: 0.0294 - accuracy: 0.9911 - val_loss: 0.3278 - val_accuracy: 0.9192 - 204ms/epoch - 6ms/step
# Epoch 61/100
# 37/37 - 0s - loss: 0.1377 - accuracy: 0.9546 - val_loss: 0.2598 - val_accuracy: 0.9136 - 205ms/epoch - 6ms/step
# Epoch 62/100
# 37/37 - 0s - loss: 0.0521 - accuracy: 0.9812 - val_loss: 0.1873 - val_accuracy: 0.9402 - 205ms/epoch - 6ms/step
# Epoch 63/100
# 37/37 - 0s - loss: 0.0282 - accuracy: 0.9909 - val_loss: 0.2331 - val_accuracy: 0.9347 - 234ms/epoch - 6ms/step
# Epoch 64/100
# 37/37 - 0s - loss: 0.0521 - accuracy: 0.9817 - val_loss: 0.2022 - val_accuracy: 0.9413 - 212ms/epoch - 6ms/step
# Epoch 65/100
# 37/37 - 0s - loss: 0.0259 - accuracy: 0.9925 - val_loss: 0.1851 - val_accuracy: 0.9513 - 238ms/epoch - 6ms/step
# Epoch 66/100
# 37/37 - 0s - loss: 0.0142 - accuracy: 0.9956 - val_loss: 0.1695 - val_accuracy: 0.9502 - 213ms/epoch - 6ms/step
# Epoch 67/100
# 37/37 - 0s - loss: 0.0148 - accuracy: 0.9956 - val_loss: 0.1683 - val_accuracy: 0.9424 - 213ms/epoch - 6ms/step
# Epoch 68/100
# 37/37 - 0s - loss: 0.0103 - accuracy: 0.9978 - val_loss: 0.1903 - val_accuracy: 0.9502 - 246ms/epoch - 7ms/step
# Epoch 69/100
# 37/37 - 0s - loss: 0.0125 - accuracy: 0.9961 - val_loss: 0.1819 - val_accuracy: 0.9502 - 204ms/epoch - 6ms/step
# Epoch 70/100
# 37/37 - 0s - loss: 0.0095 - accuracy: 0.9981 - val_loss: 0.2357 - val_accuracy: 0.9391 - 236ms/epoch - 6ms/step
# Epoch 71/100
# 37/37 - 0s - loss: 0.0057 - accuracy: 0.9983 - val_loss: 0.1770 - val_accuracy: 0.9491 - 203ms/epoch - 5ms/step
# Epoch 72/100
# 37/37 - 0s - loss: 0.0105 - accuracy: 0.9970 - val_loss: 0.1787 - val_accuracy: 0.9435 - 205ms/epoch - 6ms/step
# Epoch 73/100
# 37/37 - 0s - loss: 0.0167 - accuracy: 0.9931 - val_loss: 0.2171 - val_accuracy: 0.9446 - 207ms/epoch - 6ms/step
# Epoch 74/100
# 37/37 - 0s - loss: 0.0512 - accuracy: 0.9831 - val_loss: 0.2546 - val_accuracy: 0.9280 - 215ms/epoch - 6ms/step
# Epoch 75/100
# 37/37 - 0s - loss: 0.1108 - accuracy: 0.9656 - val_loss: 0.2560 - val_accuracy: 0.9324 - 211ms/epoch - 6ms/step
# Epoch 76/100
# 37/37 - 0s - loss: 0.0401 - accuracy: 0.9886 - val_loss: 0.2258 - val_accuracy: 0.9302 - 261ms/epoch - 7ms/step
# Epoch 77/100
# 37/37 - 0s - loss: 0.0312 - accuracy: 0.9884 - val_loss: 0.1740 - val_accuracy: 0.9457 - 216ms/epoch - 6ms/step
# Epoch 78/100
# 37/37 - 0s - loss: 0.0102 - accuracy: 0.9983 - val_loss: 0.1869 - val_accuracy: 0.9468 - 271ms/epoch - 7ms/step
# Epoch 79/100
# 37/37 - 0s - loss: 0.0108 - accuracy: 0.9970 - val_loss: 0.1891 - val_accuracy: 0.9524 - 229ms/epoch - 6ms/step
# Epoch 80/100
# 37/37 - 0s - loss: 0.0090 - accuracy: 0.9978 - val_loss: 0.1954 - val_accuracy: 0.9468 - 212ms/epoch - 6ms/step
# Epoch 81/100
# 37/37 - 0s - loss: 0.0105 - accuracy: 0.9967 - val_loss: 0.2133 - val_accuracy: 0.9502 - 224ms/epoch - 6ms/step
# Epoch 82/100
# 37/37 - 0s - loss: 0.0218 - accuracy: 0.9928 - val_loss: 0.2194 - val_accuracy: 0.9457 - 253ms/epoch - 7ms/step
# Epoch 83/100
# 37/37 - 0s - loss: 0.0148 - accuracy: 0.9953 - val_loss: 0.2329 - val_accuracy: 0.9424 - 216ms/epoch - 6ms/step
# Epoch 84/100
# 37/37 - 0s - loss: 0.0263 - accuracy: 0.9906 - val_loss: 0.2356 - val_accuracy: 0.9380 - 244ms/epoch - 7ms/step
# Epoch 85/100
# 37/37 - 0s - loss: 0.0144 - accuracy: 0.9967 - val_loss: 0.2374 - val_accuracy: 0.9424 - 205ms/epoch - 6ms/step
# Epoch 86/100
# 37/37 - 0s - loss: 0.0077 - accuracy: 0.9981 - val_loss: 0.2092 - val_accuracy: 0.9480 - 247ms/epoch - 7ms/step
# Epoch 87/100
# 37/37 - 0s - loss: 0.0041 - accuracy: 0.9989 - val_loss: 0.2220 - val_accuracy: 0.9513 - 244ms/epoch - 7ms/step
# Epoch 88/100
# 37/37 - 0s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2269 - val_accuracy: 0.9480 - 244ms/epoch - 7ms/step
# Epoch 89/100
# 37/37 - 0s - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.2627 - val_accuracy: 0.9380 - 252ms/epoch - 7ms/step
# Epoch 90/100
# 37/37 - 0s - loss: 0.0035 - accuracy: 0.9997 - val_loss: 0.1967 - val_accuracy: 0.9480 - 235ms/epoch - 6ms/step
# Epoch 91/100
# 37/37 - 0s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2289 - val_accuracy: 0.9480 - 226ms/epoch - 6ms/step
# Epoch 92/100
# 37/37 - 0s - loss: 0.0046 - accuracy: 0.9983 - val_loss: 0.2154 - val_accuracy: 0.9446 - 215ms/epoch - 6ms/step
# Epoch 93/100
# 37/37 - 0s - loss: 0.0058 - accuracy: 0.9978 - val_loss: 0.2795 - val_accuracy: 0.9391 - 246ms/epoch - 7ms/step
# Epoch 94/100
# 37/37 - 0s - loss: 0.0242 - accuracy: 0.9914 - val_loss: 0.4409 - val_accuracy: 0.9169 - 216ms/epoch - 6ms/step
# Epoch 95/100
# 37/37 - 0s - loss: 0.0906 - accuracy: 0.9731 - val_loss: 0.2512 - val_accuracy: 0.9247 - 221ms/epoch - 6ms/step
# Epoch 96/100
# 37/37 - 0s - loss: 0.0955 - accuracy: 0.9659 - val_loss: 0.2342 - val_accuracy: 0.9302 - 236ms/epoch - 6ms/step
# Epoch 97/100
# 37/37 - 0s - loss: 0.0903 - accuracy: 0.9698 - val_loss: 0.2245 - val_accuracy: 0.9402 - 213ms/epoch - 6ms/step
# Epoch 98/100
# 37/37 - 0s - loss: 0.0269 - accuracy: 0.9895 - val_loss: 0.2306 - val_accuracy: 0.9391 - 202ms/epoch - 5ms/step
# Epoch 99/100
# 37/37 - 0s - loss: 0.0118 - accuracy: 0.9967 - val_loss: 0.2168 - val_accuracy: 0.9513 - 213ms/epoch - 6ms/step
# Epoch 100/100
# 37/37 - 0s - loss: 0.0085 - accuracy: 0.9978 - val_loss: 0.2154 - val_accuracy: 0.9446 - 213ms/epoch - 6ms/step

# %% [markdown]
# ## 評估訓練結果

# %%
def show_train_history(train_history, train, validation):

    plt.plot(train_history.history[train])

    plt.plot(train_history.history[validation])

    plt.title('Train History')

    plt.ylabel('train')

    plt.xlabel('Epoch')

    plt.legend(['train', 'validation'], loc='upper left')

    plt.show()
    

show_train_history(train_history, 'accuracy', 'val_accuracy')
show_train_history(train_history, 'loss', 'val_loss')

# %% [markdown]
# ## 使用未參與訓練的測試資料測試，模型準確率

# %%
scores = model.evaluate(X_test,y_test,verbose=0)

print('Accuracy = ', scores[1])
# Out:
# Accuracy =  0.9609929323196411

# %% [markdown]
# ## 評估訓練結果

# %%
y_pred = np.argmax(model.predict(X_test), axis=-1)
y_true = np.argmax(y_test, axis=-1)
conf_matrix = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()
# Out:
# 36/36 [==============================] - 0s 3ms/step
