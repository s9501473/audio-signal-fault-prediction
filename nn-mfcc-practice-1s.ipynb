# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import librosa
import os
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
# Out:
# 2024-01-31 08:22:47.112843: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-31 08:22:47.112992: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-31 08:22:47.243475: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ## 顯示音頻訊號圖

# %%
path = '/kaggle/input/recoding-data/UAV Recordings 1s/UAV Recordings 1s/Healthy/recording_2023-03-02_14-07-33_012.wav'

# 讀取音頻文件

plt.figure(figsize=(14,5))
data, sampling_rate = librosa.load(path)
librosa.display.waveshow(data,sr=sampling_rate)

# %% [markdown]
# ## 顯示MFCCs特徵圖

# %%
# 提取MFCCs特徵
mfccs_features = librosa.feature.mfcc(y = data, sr = sampling_rate, n_mfcc = 80)

# 繪製MFCC
plt.figure(figsize=(10, 4))
librosa.display.specshow(mfccs_features, x_axis='time', sr=sampling_rate)
plt.colorbar(format='%+2.0f dB')
plt.title('MFCC')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 加載音頻訊號

# %%
data_path = '/kaggle/input/recoding-data/UAV Recordings 1s/UAV Recordings 1s'

# %% [markdown]
# ## 音頻訊號進行MFCCs特徵提取

# %%
def load_data(data_dir):
    datasets = []
    labels = []
    categories = os.listdir(data_dir)
    for index, folder in enumerate(categories):
        for filename in os.listdir(data_dir+"/"+folder):
            data, sampling_rate = librosa.load(data_dir+"/"+folder+"/"+filename)
            mfccs_features = librosa.feature.mfcc(y=data, sr=sampling_rate, n_mfcc=80)
            mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
            datasets.append(np.array(mfccs_scaled_features))
            labels.append(categories[index])
    return np.array(datasets), np.array(labels)

datasets, labels = load_data(data_path)

# %%
datasets = datasets.astype('float32')

labelencoder = LabelEncoder()

labelsOneHot = to_categorical(labelencoder.fit_transform(labels))

# %% [markdown]
# ## 切分成訓練資料、測試資料，8:2的比例

# %%
X_train, X_test, y_train, y_test = train_test_split(datasets, labelsOneHot, test_size = 0.2, stratify = labelsOneHot, random_state = 3)

print("----------Train-------------")
print(X_train.shape)

print("----------Test--------------")
print(X_test.shape)
# Out:
# ----------Train-------------
# (4512, 80)
# ----------Test--------------
# (1128, 80)

# %% [markdown]
# ## 類別數量

# %%
num_classes = len(np.unique(labels))

# %% [markdown]
# ## 建立NN模型

# %%
model=Sequential()

#Input layer
model.add(Flatten(input_shape=(80,)))

#hidden layer 1
model.add(Dense(512, Activation('relu')))

#hidden layer 2
model.add(Dense(128, Activation('relu')))

#hidden layer 3
model.add(Dense(64, Activation('relu')))

# 使用Dropout防止過度擬合
model.add(Dropout(0.25))

#Output layer
model.add(Dense(num_classes, Activation('softmax')))

# %%
# 選擇損失函數、優化方法及成效衡量方式
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 80)                0
#
#  dense (Dense)               (None, 512)               41472
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_3 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 115717 (452.02 KB)
# Trainable params: 115717 (452.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 模型訓練

# %%
train_history = model.fit(X_train, y_train, validation_split=0.2, batch_size = 100, epochs = 100, verbose=2)
# Out:
# Epoch 1/100
# 37/37 - 1s - loss: 1.3767 - accuracy: 0.5024 - val_loss: 0.8919 - val_accuracy: 0.6523 - 1s/epoch - 40ms/step
# Epoch 2/100
# 37/37 - 0s - loss: 0.7737 - accuracy: 0.6952 - val_loss: 0.5744 - val_accuracy: 0.7752 - 224ms/epoch - 6ms/step
# Epoch 3/100
# 37/37 - 0s - loss: 0.6053 - accuracy: 0.7689 - val_loss: 0.4950 - val_accuracy: 0.8228 - 180ms/epoch - 5ms/step
# Epoch 4/100
# 37/37 - 0s - loss: 0.4816 - accuracy: 0.8171 - val_loss: 0.4399 - val_accuracy: 0.8272 - 178ms/epoch - 5ms/step
# Epoch 5/100
# 37/37 - 0s - loss: 0.4299 - accuracy: 0.8376 - val_loss: 0.3944 - val_accuracy: 0.8317 - 183ms/epoch - 5ms/step
# Epoch 6/100
# 37/37 - 0s - loss: 0.3881 - accuracy: 0.8567 - val_loss: 0.3791 - val_accuracy: 0.8483 - 185ms/epoch - 5ms/step
# Epoch 7/100
# 37/37 - 0s - loss: 0.3484 - accuracy: 0.8667 - val_loss: 0.3498 - val_accuracy: 0.8682 - 183ms/epoch - 5ms/step
# Epoch 8/100
# 37/37 - 0s - loss: 0.3407 - accuracy: 0.8756 - val_loss: 0.4342 - val_accuracy: 0.8217 - 212ms/epoch - 6ms/step
# Epoch 9/100
# 37/37 - 0s - loss: 0.4150 - accuracy: 0.8476 - val_loss: 0.3172 - val_accuracy: 0.8837 - 201ms/epoch - 5ms/step
# Epoch 10/100
# 37/37 - 0s - loss: 0.2913 - accuracy: 0.8958 - val_loss: 0.3282 - val_accuracy: 0.8627 - 184ms/epoch - 5ms/step
# Epoch 11/100
# 37/37 - 0s - loss: 0.2921 - accuracy: 0.8878 - val_loss: 0.2470 - val_accuracy: 0.9214 - 223ms/epoch - 6ms/step
# Epoch 12/100
# 37/37 - 0s - loss: 0.2633 - accuracy: 0.9036 - val_loss: 0.3291 - val_accuracy: 0.8948 - 168ms/epoch - 5ms/step
# Epoch 13/100
# 37/37 - 0s - loss: 0.2580 - accuracy: 0.9005 - val_loss: 0.2244 - val_accuracy: 0.9136 - 175ms/epoch - 5ms/step
# Epoch 14/100
# 37/37 - 0s - loss: 0.2099 - accuracy: 0.9194 - val_loss: 0.2557 - val_accuracy: 0.9048 - 180ms/epoch - 5ms/step
# Epoch 15/100
# 37/37 - 0s - loss: 0.2319 - accuracy: 0.9141 - val_loss: 0.2646 - val_accuracy: 0.8959 - 176ms/epoch - 5ms/step
# Epoch 16/100
# 37/37 - 0s - loss: 0.1951 - accuracy: 0.9299 - val_loss: 0.2260 - val_accuracy: 0.9114 - 222ms/epoch - 6ms/step
# Epoch 17/100
# 37/37 - 0s - loss: 0.1916 - accuracy: 0.9291 - val_loss: 0.2385 - val_accuracy: 0.9103 - 173ms/epoch - 5ms/step
# Epoch 18/100
# 37/37 - 0s - loss: 0.1571 - accuracy: 0.9476 - val_loss: 0.2483 - val_accuracy: 0.9158 - 176ms/epoch - 5ms/step
# Epoch 19/100
# 37/37 - 0s - loss: 0.1786 - accuracy: 0.9335 - val_loss: 0.2208 - val_accuracy: 0.9225 - 173ms/epoch - 5ms/step
# Epoch 20/100
# 37/37 - 0s - loss: 0.1557 - accuracy: 0.9426 - val_loss: 0.2045 - val_accuracy: 0.9291 - 183ms/epoch - 5ms/step
# Epoch 21/100
# 37/37 - 0s - loss: 0.1340 - accuracy: 0.9546 - val_loss: 0.2135 - val_accuracy: 0.9192 - 181ms/epoch - 5ms/step
# Epoch 22/100
# 37/37 - 0s - loss: 0.1452 - accuracy: 0.9493 - val_loss: 0.2241 - val_accuracy: 0.9291 - 222ms/epoch - 6ms/step
# Epoch 23/100
# 37/37 - 0s - loss: 0.1603 - accuracy: 0.9410 - val_loss: 0.2030 - val_accuracy: 0.9291 - 221ms/epoch - 6ms/step
# Epoch 24/100
# 37/37 - 0s - loss: 0.1298 - accuracy: 0.9496 - val_loss: 0.2442 - val_accuracy: 0.9236 - 179ms/epoch - 5ms/step
# Epoch 25/100
# 37/37 - 0s - loss: 0.1761 - accuracy: 0.9349 - val_loss: 0.2356 - val_accuracy: 0.9291 - 180ms/epoch - 5ms/step
# Epoch 26/100
# 37/37 - 0s - loss: 0.1375 - accuracy: 0.9512 - val_loss: 0.2041 - val_accuracy: 0.9302 - 174ms/epoch - 5ms/step
# Epoch 27/100
# 37/37 - 0s - loss: 0.1015 - accuracy: 0.9676 - val_loss: 0.2027 - val_accuracy: 0.9302 - 182ms/epoch - 5ms/step
# Epoch 28/100
# 37/37 - 0s - loss: 0.1078 - accuracy: 0.9609 - val_loss: 0.2003 - val_accuracy: 0.9291 - 223ms/epoch - 6ms/step
# Epoch 29/100
# 37/37 - 0s - loss: 0.1127 - accuracy: 0.9587 - val_loss: 0.1742 - val_accuracy: 0.9369 - 219ms/epoch - 6ms/step
# Epoch 30/100
# 37/37 - 0s - loss: 0.1147 - accuracy: 0.9582 - val_loss: 0.1989 - val_accuracy: 0.9358 - 190ms/epoch - 5ms/step
# Epoch 31/100
# 37/37 - 0s - loss: 0.0985 - accuracy: 0.9645 - val_loss: 0.2160 - val_accuracy: 0.9369 - 179ms/epoch - 5ms/step
# Epoch 32/100
# 37/37 - 0s - loss: 0.1123 - accuracy: 0.9593 - val_loss: 0.1900 - val_accuracy: 0.9302 - 179ms/epoch - 5ms/step
# Epoch 33/100
# 37/37 - 0s - loss: 0.0693 - accuracy: 0.9764 - val_loss: 0.1827 - val_accuracy: 0.9391 - 180ms/epoch - 5ms/step
# Epoch 34/100
# 37/37 - 0s - loss: 0.0693 - accuracy: 0.9776 - val_loss: 0.1751 - val_accuracy: 0.9502 - 174ms/epoch - 5ms/step
# Epoch 35/100
# 37/37 - 0s - loss: 0.0509 - accuracy: 0.9837 - val_loss: 0.1920 - val_accuracy: 0.9402 - 180ms/epoch - 5ms/step
# Epoch 36/100
# 37/37 - 0s - loss: 0.0680 - accuracy: 0.9773 - val_loss: 0.2007 - val_accuracy: 0.9380 - 228ms/epoch - 6ms/step
# Epoch 37/100
# 37/37 - 0s - loss: 0.0662 - accuracy: 0.9770 - val_loss: 0.2059 - val_accuracy: 0.9358 - 249ms/epoch - 7ms/step
# Epoch 38/100
# 37/37 - 0s - loss: 0.0686 - accuracy: 0.9773 - val_loss: 0.2471 - val_accuracy: 0.9203 - 232ms/epoch - 6ms/step
# Epoch 39/100
# 37/37 - 0s - loss: 0.0735 - accuracy: 0.9737 - val_loss: 0.2087 - val_accuracy: 0.9380 - 233ms/epoch - 6ms/step
# Epoch 40/100
# 37/37 - 0s - loss: 0.0569 - accuracy: 0.9800 - val_loss: 0.1953 - val_accuracy: 0.9413 - 258ms/epoch - 7ms/step
# Epoch 41/100
# 37/37 - 0s - loss: 0.0459 - accuracy: 0.9850 - val_loss: 0.2268 - val_accuracy: 0.9380 - 199ms/epoch - 5ms/step
# Epoch 42/100
# 37/37 - 0s - loss: 0.0641 - accuracy: 0.9792 - val_loss: 0.1935 - val_accuracy: 0.9391 - 195ms/epoch - 5ms/step
# Epoch 43/100
# 37/37 - 0s - loss: 0.0473 - accuracy: 0.9828 - val_loss: 0.2080 - val_accuracy: 0.9424 - 175ms/epoch - 5ms/step
# Epoch 44/100
# 37/37 - 0s - loss: 0.0567 - accuracy: 0.9795 - val_loss: 0.2448 - val_accuracy: 0.9402 - 185ms/epoch - 5ms/step
# Epoch 45/100
# 37/37 - 0s - loss: 0.0489 - accuracy: 0.9806 - val_loss: 0.2160 - val_accuracy: 0.9380 - 213ms/epoch - 6ms/step
# Epoch 46/100
# 37/37 - 0s - loss: 0.0335 - accuracy: 0.9897 - val_loss: 0.2454 - val_accuracy: 0.9391 - 184ms/epoch - 5ms/step
# Epoch 47/100
# 37/37 - 0s - loss: 0.0317 - accuracy: 0.9909 - val_loss: 0.2474 - val_accuracy: 0.9358 - 176ms/epoch - 5ms/step
# Epoch 48/100
# 37/37 - 0s - loss: 0.0582 - accuracy: 0.9803 - val_loss: 0.2456 - val_accuracy: 0.9291 - 179ms/epoch - 5ms/step
# Epoch 49/100
# 37/37 - 0s - loss: 0.0438 - accuracy: 0.9848 - val_loss: 0.2316 - val_accuracy: 0.9391 - 181ms/epoch - 5ms/step
# Epoch 50/100
# 37/37 - 0s - loss: 0.0270 - accuracy: 0.9928 - val_loss: 0.2019 - val_accuracy: 0.9457 - 182ms/epoch - 5ms/step
# Epoch 51/100
# 37/37 - 0s - loss: 0.0224 - accuracy: 0.9942 - val_loss: 0.2122 - val_accuracy: 0.9435 - 219ms/epoch - 6ms/step
# Epoch 52/100
# 37/37 - 0s - loss: 0.0254 - accuracy: 0.9906 - val_loss: 0.2225 - val_accuracy: 0.9424 - 171ms/epoch - 5ms/step
# Epoch 53/100
# 37/37 - 0s - loss: 0.0276 - accuracy: 0.9928 - val_loss: 0.2055 - val_accuracy: 0.9457 - 182ms/epoch - 5ms/step
# Epoch 54/100
# 37/37 - 0s - loss: 0.0364 - accuracy: 0.9873 - val_loss: 0.2598 - val_accuracy: 0.9324 - 167ms/epoch - 5ms/step
# Epoch 55/100
# 37/37 - 0s - loss: 0.0781 - accuracy: 0.9745 - val_loss: 0.2750 - val_accuracy: 0.9347 - 176ms/epoch - 5ms/step
# Epoch 56/100
# 37/37 - 0s - loss: 0.0385 - accuracy: 0.9875 - val_loss: 0.2337 - val_accuracy: 0.9402 - 177ms/epoch - 5ms/step
# Epoch 57/100
# 37/37 - 0s - loss: 0.0534 - accuracy: 0.9817 - val_loss: 0.2158 - val_accuracy: 0.9435 - 198ms/epoch - 5ms/step
# Epoch 58/100
# 37/37 - 0s - loss: 0.0544 - accuracy: 0.9806 - val_loss: 0.2660 - val_accuracy: 0.9269 - 188ms/epoch - 5ms/step
# Epoch 59/100
# 37/37 - 0s - loss: 0.0286 - accuracy: 0.9920 - val_loss: 0.2443 - val_accuracy: 0.9369 - 194ms/epoch - 5ms/step
# Epoch 60/100
# 37/37 - 0s - loss: 0.0257 - accuracy: 0.9920 - val_loss: 0.2316 - val_accuracy: 0.9424 - 224ms/epoch - 6ms/step
# Epoch 61/100
# 37/37 - 0s - loss: 0.0970 - accuracy: 0.9717 - val_loss: 0.1836 - val_accuracy: 0.9491 - 184ms/epoch - 5ms/step
# Epoch 62/100
# 37/37 - 0s - loss: 0.0413 - accuracy: 0.9867 - val_loss: 0.2432 - val_accuracy: 0.9347 - 192ms/epoch - 5ms/step
# Epoch 63/100
# 37/37 - 0s - loss: 0.0821 - accuracy: 0.9690 - val_loss: 0.2463 - val_accuracy: 0.9258 - 174ms/epoch - 5ms/step
# Epoch 64/100
# 37/37 - 0s - loss: 0.0397 - accuracy: 0.9886 - val_loss: 0.2463 - val_accuracy: 0.9269 - 179ms/epoch - 5ms/step
# Epoch 65/100
# 37/37 - 0s - loss: 0.0232 - accuracy: 0.9933 - val_loss: 0.2016 - val_accuracy: 0.9502 - 178ms/epoch - 5ms/step
# Epoch 66/100
# 37/37 - 0s - loss: 0.0157 - accuracy: 0.9947 - val_loss: 0.2056 - val_accuracy: 0.9446 - 223ms/epoch - 6ms/step
# Epoch 67/100
# 37/37 - 0s - loss: 0.0128 - accuracy: 0.9964 - val_loss: 0.2438 - val_accuracy: 0.9424 - 223ms/epoch - 6ms/step
# Epoch 68/100
# 37/37 - 0s - loss: 0.0120 - accuracy: 0.9970 - val_loss: 0.2558 - val_accuracy: 0.9402 - 174ms/epoch - 5ms/step
# Epoch 69/100
# 37/37 - 0s - loss: 0.0109 - accuracy: 0.9975 - val_loss: 0.2465 - val_accuracy: 0.9435 - 172ms/epoch - 5ms/step
# Epoch 70/100
# 37/37 - 0s - loss: 0.0278 - accuracy: 0.9886 - val_loss: 0.2262 - val_accuracy: 0.9402 - 172ms/epoch - 5ms/step
# Epoch 71/100
# 37/37 - 0s - loss: 0.0276 - accuracy: 0.9911 - val_loss: 0.2957 - val_accuracy: 0.9280 - 179ms/epoch - 5ms/step
# Epoch 72/100
# 37/37 - 0s - loss: 0.0450 - accuracy: 0.9850 - val_loss: 0.2485 - val_accuracy: 0.9358 - 184ms/epoch - 5ms/step
# Epoch 73/100
# 37/37 - 0s - loss: 0.0317 - accuracy: 0.9897 - val_loss: 0.2119 - val_accuracy: 0.9513 - 217ms/epoch - 6ms/step
# Epoch 74/100
# 37/37 - 0s - loss: 0.0134 - accuracy: 0.9958 - val_loss: 0.2380 - val_accuracy: 0.9502 - 185ms/epoch - 5ms/step
# Epoch 75/100
# 37/37 - 0s - loss: 0.0204 - accuracy: 0.9936 - val_loss: 0.2849 - val_accuracy: 0.9203 - 218ms/epoch - 6ms/step
# Epoch 76/100
# 37/37 - 0s - loss: 0.0231 - accuracy: 0.9917 - val_loss: 0.2622 - val_accuracy: 0.9380 - 181ms/epoch - 5ms/step
# Epoch 77/100
# 37/37 - 0s - loss: 0.0222 - accuracy: 0.9939 - val_loss: 0.2142 - val_accuracy: 0.9535 - 184ms/epoch - 5ms/step
# Epoch 78/100
# 37/37 - 0s - loss: 0.0165 - accuracy: 0.9933 - val_loss: 0.2647 - val_accuracy: 0.9347 - 179ms/epoch - 5ms/step
# Epoch 79/100
# 37/37 - 0s - loss: 0.0218 - accuracy: 0.9922 - val_loss: 0.3112 - val_accuracy: 0.9280 - 179ms/epoch - 5ms/step
# Epoch 80/100
# 37/37 - 0s - loss: 0.0317 - accuracy: 0.9897 - val_loss: 0.2286 - val_accuracy: 0.9435 - 184ms/epoch - 5ms/step
# Epoch 81/100
# 37/37 - 0s - loss: 0.0199 - accuracy: 0.9928 - val_loss: 0.2633 - val_accuracy: 0.9391 - 181ms/epoch - 5ms/step
# Epoch 82/100
# 37/37 - 0s - loss: 0.0304 - accuracy: 0.9906 - val_loss: 0.2389 - val_accuracy: 0.9457 - 179ms/epoch - 5ms/step
# Epoch 83/100
# 37/37 - 0s - loss: 0.0531 - accuracy: 0.9803 - val_loss: 0.2873 - val_accuracy: 0.9291 - 217ms/epoch - 6ms/step
# Epoch 84/100
# 37/37 - 0s - loss: 0.0196 - accuracy: 0.9939 - val_loss: 0.2321 - val_accuracy: 0.9468 - 171ms/epoch - 5ms/step
# Epoch 85/100
# 37/37 - 0s - loss: 0.0077 - accuracy: 0.9983 - val_loss: 0.2422 - val_accuracy: 0.9424 - 175ms/epoch - 5ms/step
# Epoch 86/100
# 37/37 - 0s - loss: 0.0109 - accuracy: 0.9967 - val_loss: 0.2610 - val_accuracy: 0.9457 - 175ms/epoch - 5ms/step
# Epoch 87/100
# 37/37 - 0s - loss: 0.0141 - accuracy: 0.9945 - val_loss: 0.3362 - val_accuracy: 0.9380 - 178ms/epoch - 5ms/step
# Epoch 88/100
# 37/37 - 0s - loss: 0.0967 - accuracy: 0.9662 - val_loss: 0.4008 - val_accuracy: 0.9181 - 176ms/epoch - 5ms/step
# Epoch 89/100
# 37/37 - 0s - loss: 0.0752 - accuracy: 0.9756 - val_loss: 0.2614 - val_accuracy: 0.9347 - 174ms/epoch - 5ms/step
# Epoch 90/100
# 37/37 - 0s - loss: 0.0339 - accuracy: 0.9897 - val_loss: 0.2702 - val_accuracy: 0.9391 - 167ms/epoch - 5ms/step
# Epoch 91/100
# 37/37 - 0s - loss: 0.0336 - accuracy: 0.9886 - val_loss: 0.2342 - val_accuracy: 0.9446 - 210ms/epoch - 6ms/step
# Epoch 92/100
# 37/37 - 0s - loss: 0.0174 - accuracy: 0.9950 - val_loss: 0.2306 - val_accuracy: 0.9424 - 180ms/epoch - 5ms/step
# Epoch 93/100
# 37/37 - 0s - loss: 0.0064 - accuracy: 0.9994 - val_loss: 0.2120 - val_accuracy: 0.9524 - 168ms/epoch - 5ms/step
# Epoch 94/100
# 37/37 - 0s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2061 - val_accuracy: 0.9568 - 180ms/epoch - 5ms/step
# Epoch 95/100
# 37/37 - 0s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2347 - val_accuracy: 0.9546 - 171ms/epoch - 5ms/step
# Epoch 96/100
# 37/37 - 0s - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.2546 - val_accuracy: 0.9480 - 176ms/epoch - 5ms/step
# Epoch 97/100
# 37/37 - 0s - loss: 0.0033 - accuracy: 0.9994 - val_loss: 0.2332 - val_accuracy: 0.9546 - 168ms/epoch - 5ms/step
# Epoch 98/100
# 37/37 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2211 - val_accuracy: 0.9557 - 180ms/epoch - 5ms/step
# Epoch 99/100
# 37/37 - 0s - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.2664 - val_accuracy: 0.9491 - 177ms/epoch - 5ms/step
# Epoch 100/100
# 37/37 - 0s - loss: 0.0215 - accuracy: 0.9925 - val_loss: 0.2425 - val_accuracy: 0.9502 - 173ms/epoch - 5ms/step

# %% [markdown]
# ## 評估訓練結果

# %%
def show_train_history(train_history, train, validation):

    plt.plot(train_history.history[train])

    plt.plot(train_history.history[validation])

    plt.title('Train History')

    plt.ylabel('train')

    plt.xlabel('Epoch')

    plt.legend(['train', 'validation'], loc='upper left')

    plt.show()
    

show_train_history(train_history, 'accuracy', 'val_accuracy')
show_train_history(train_history, 'loss', 'val_loss')

# %% [markdown]
# ## 使用未參與訓練的測試資料測試，模型準確率

# %%
scores = model.evaluate(X_test,y_test,verbose=0)

print('Accuracy = ', scores[1])
# Out:
# Accuracy =  0.957446813583374

# %% [markdown]
# ## 評估訓練結果

# %%
y_pred = np.argmax(model.predict(X_test), axis=-1)
y_true = np.argmax(y_test, axis=-1)
conf_matrix = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()
# Out:
# 36/36 [==============================] - 0s 2ms/step
