# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import librosa
import os
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## 加載音頻訊號

# %%
data_path = '/kaggle/input/recoding-data/UAV Recordings 3s/UAV Recordings 3s'

# %% [markdown]
# ## 音頻訊號進行STFT特徵提取

# %%
def load_data(data_dir):
    datasets = []
    labels = []
    categories = os.listdir(data_dir)
    for index, folder in enumerate(categories):
        for filename in os.listdir(data_dir+"/"+folder):
            data, sampling_rate = librosa.load(data_dir+"/"+folder+"/"+filename)
            stft_feature = np.abs(librosa.stft(data))
            scaled_features = np.mean(stft_feature.T,axis=0)
            datasets.append(np.array(scaled_features))
            labels.append(categories[index])
    return np.array(datasets), np.array(labels)

datasets, labels = load_data(data_path)

# %%
datasets = datasets.astype('float32')

labelencoder = LabelEncoder()

labelsOneHot = to_categorical(labelencoder.fit_transform(labels))

# %% [markdown]
# ## 切分成訓練資料、測試資料，8:2的比例

# %%
X_train, X_test, y_train, y_test = train_test_split(datasets, labelsOneHot, test_size = 0.2, stratify = labelsOneHot, random_state = 3)

print("----------Train-------------")
print(X_train.shape)

print("----------Test--------------")
print(X_test.shape)
# Out:
# ----------Train-------------
# (1504, 1025)
# ----------Test--------------
# (376, 1025)

# %% [markdown]
# ## 類別數量

# %%
num_classes = len(np.unique(labels))

# %% [markdown]
# ## 建立NN模型

# %%
model=Sequential()

#Input layer
model.add(Flatten(input_shape=(datasets.shape[1],)))

#hidden layer 1
model.add(Dense(512, Activation('relu')))

#hidden layer 2
model.add(Dense(128, Activation('relu')))

#hidden layer 3
model.add(Dense(64, Activation('relu')))

# 使用Dropout防止過度擬合
model.add(Dropout(0.25))

#Output layer
model.add(Dense(num_classes, Activation('softmax')))

# %%
# 選擇損失函數、優化方法及成效衡量方式
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 1025)              0
#
#  dense_4 (Dense)             (None, 512)               525312
#
#  dense_5 (Dense)             (None, 128)               65664
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 599557 (2.29 MB)
# Trainable params: 599557 (2.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 模型訓練

# %%
train_history = model.fit(X_train, y_train, validation_split=0.2, batch_size = 100, epochs = 150, verbose=2)
# Out:
# Epoch 1/150
# 13/13 - 1s - loss: 5.2192 - accuracy: 0.2344 - val_loss: 1.5765 - val_accuracy: 0.3920 - 889ms/epoch - 68ms/step
# Epoch 2/150
# 13/13 - 0s - loss: 1.6500 - accuracy: 0.3491 - val_loss: 1.4908 - val_accuracy: 0.3953 - 106ms/epoch - 8ms/step
# Epoch 3/150
# 13/13 - 0s - loss: 1.4545 - accuracy: 0.4131 - val_loss: 1.4079 - val_accuracy: 0.3987 - 105ms/epoch - 8ms/step
# Epoch 4/150
# 13/13 - 0s - loss: 1.4263 - accuracy: 0.3965 - val_loss: 1.3432 - val_accuracy: 0.5449 - 102ms/epoch - 8ms/step
# Epoch 5/150
# 13/13 - 0s - loss: 1.3829 - accuracy: 0.4406 - val_loss: 1.2273 - val_accuracy: 0.5449 - 125ms/epoch - 10ms/step
# Epoch 6/150
# 13/13 - 0s - loss: 1.3567 - accuracy: 0.4289 - val_loss: 1.1998 - val_accuracy: 0.5249 - 130ms/epoch - 10ms/step
# Epoch 7/150
# 13/13 - 0s - loss: 1.2994 - accuracy: 0.4464 - val_loss: 1.2922 - val_accuracy: 0.4684 - 130ms/epoch - 10ms/step
# Epoch 8/150
# 13/13 - 0s - loss: 1.3466 - accuracy: 0.4223 - val_loss: 1.4279 - val_accuracy: 0.3522 - 112ms/epoch - 9ms/step
# Epoch 9/150
# 13/13 - 0s - loss: 1.4188 - accuracy: 0.3915 - val_loss: 1.3176 - val_accuracy: 0.4884 - 116ms/epoch - 9ms/step
# Epoch 10/150
# 13/13 - 0s - loss: 1.3260 - accuracy: 0.4414 - val_loss: 1.2100 - val_accuracy: 0.5150 - 111ms/epoch - 9ms/step
# Epoch 11/150
# 13/13 - 0s - loss: 1.2410 - accuracy: 0.4605 - val_loss: 1.1029 - val_accuracy: 0.5482 - 111ms/epoch - 9ms/step
# Epoch 12/150
# 13/13 - 0s - loss: 1.1830 - accuracy: 0.5245 - val_loss: 1.3243 - val_accuracy: 0.4983 - 113ms/epoch - 9ms/step
# Epoch 13/150
# 13/13 - 0s - loss: 1.3315 - accuracy: 0.4464 - val_loss: 1.0755 - val_accuracy: 0.5548 - 114ms/epoch - 9ms/step
# Epoch 14/150
# 13/13 - 0s - loss: 1.1542 - accuracy: 0.5029 - val_loss: 1.3627 - val_accuracy: 0.3854 - 100ms/epoch - 8ms/step
# Epoch 15/150
# 13/13 - 0s - loss: 1.2561 - accuracy: 0.4855 - val_loss: 1.1816 - val_accuracy: 0.5615 - 105ms/epoch - 8ms/step
# Epoch 16/150
# 13/13 - 0s - loss: 1.2240 - accuracy: 0.4672 - val_loss: 1.2115 - val_accuracy: 0.4850 - 102ms/epoch - 8ms/step
# Epoch 17/150
# 13/13 - 0s - loss: 1.1921 - accuracy: 0.4946 - val_loss: 1.1134 - val_accuracy: 0.5615 - 103ms/epoch - 8ms/step
# Epoch 18/150
# 13/13 - 0s - loss: 1.2509 - accuracy: 0.4863 - val_loss: 1.5926 - val_accuracy: 0.4186 - 121ms/epoch - 9ms/step
# Epoch 19/150
# 13/13 - 0s - loss: 1.2628 - accuracy: 0.4755 - val_loss: 1.1312 - val_accuracy: 0.5249 - 126ms/epoch - 10ms/step
# Epoch 20/150
# 13/13 - 0s - loss: 1.1628 - accuracy: 0.4996 - val_loss: 1.3061 - val_accuracy: 0.4684 - 104ms/epoch - 8ms/step
# Epoch 21/150
# 13/13 - 0s - loss: 1.1562 - accuracy: 0.5137 - val_loss: 0.9780 - val_accuracy: 0.5681 - 106ms/epoch - 8ms/step
# Epoch 22/150
# 13/13 - 0s - loss: 1.0650 - accuracy: 0.5287 - val_loss: 0.9856 - val_accuracy: 0.5681 - 109ms/epoch - 8ms/step
# Epoch 23/150
# 13/13 - 0s - loss: 1.0671 - accuracy: 0.5594 - val_loss: 1.1584 - val_accuracy: 0.5548 - 101ms/epoch - 8ms/step
# Epoch 24/150
# 13/13 - 0s - loss: 1.1161 - accuracy: 0.5270 - val_loss: 1.0051 - val_accuracy: 0.5814 - 107ms/epoch - 8ms/step
# Epoch 25/150
# 13/13 - 0s - loss: 1.0502 - accuracy: 0.5619 - val_loss: 1.6984 - val_accuracy: 0.2625 - 117ms/epoch - 9ms/step
# Epoch 26/150
# 13/13 - 0s - loss: 1.5108 - accuracy: 0.3666 - val_loss: 1.1614 - val_accuracy: 0.5482 - 101ms/epoch - 8ms/step
# Epoch 27/150
# 13/13 - 0s - loss: 1.2823 - accuracy: 0.4522 - val_loss: 1.1874 - val_accuracy: 0.4850 - 116ms/epoch - 9ms/step
# Epoch 28/150
# 13/13 - 0s - loss: 1.2834 - accuracy: 0.4331 - val_loss: 1.1807 - val_accuracy: 0.5183 - 110ms/epoch - 8ms/step
# Epoch 29/150
# 13/13 - 0s - loss: 1.1964 - accuracy: 0.4738 - val_loss: 1.1173 - val_accuracy: 0.4850 - 112ms/epoch - 9ms/step
# Epoch 30/150
# 13/13 - 0s - loss: 1.1233 - accuracy: 0.4697 - val_loss: 1.0746 - val_accuracy: 0.4950 - 103ms/epoch - 8ms/step
# Epoch 31/150
# 13/13 - 0s - loss: 1.1434 - accuracy: 0.4705 - val_loss: 1.1288 - val_accuracy: 0.4950 - 107ms/epoch - 8ms/step
# Epoch 32/150
# 13/13 - 0s - loss: 1.1216 - accuracy: 0.5137 - val_loss: 1.0336 - val_accuracy: 0.5714 - 103ms/epoch - 8ms/step
# Epoch 33/150
# 13/13 - 0s - loss: 1.0902 - accuracy: 0.5353 - val_loss: 1.0002 - val_accuracy: 0.4983 - 105ms/epoch - 8ms/step
# Epoch 34/150
# 13/13 - 0s - loss: 1.0816 - accuracy: 0.5029 - val_loss: 0.9728 - val_accuracy: 0.5415 - 102ms/epoch - 8ms/step
# Epoch 35/150
# 13/13 - 0s - loss: 1.1005 - accuracy: 0.5179 - val_loss: 0.9988 - val_accuracy: 0.5714 - 104ms/epoch - 8ms/step
# Epoch 36/150
# 13/13 - 0s - loss: 1.0771 - accuracy: 0.5195 - val_loss: 0.9384 - val_accuracy: 0.6179 - 115ms/epoch - 9ms/step
# Epoch 37/150
# 13/13 - 0s - loss: 1.0446 - accuracy: 0.5029 - val_loss: 1.0141 - val_accuracy: 0.5017 - 108ms/epoch - 8ms/step
# Epoch 38/150
# 13/13 - 0s - loss: 1.0941 - accuracy: 0.5320 - val_loss: 1.0413 - val_accuracy: 0.5482 - 102ms/epoch - 8ms/step
# Epoch 39/150
# 13/13 - 0s - loss: 1.0216 - accuracy: 0.5669 - val_loss: 0.9426 - val_accuracy: 0.6146 - 106ms/epoch - 8ms/step
# Epoch 40/150
# 13/13 - 0s - loss: 0.9952 - accuracy: 0.5752 - val_loss: 0.9070 - val_accuracy: 0.6578 - 101ms/epoch - 8ms/step
# Epoch 41/150
# 13/13 - 0s - loss: 1.0016 - accuracy: 0.5694 - val_loss: 0.9276 - val_accuracy: 0.6844 - 113ms/epoch - 9ms/step
# Epoch 42/150
# 13/13 - 0s - loss: 0.9904 - accuracy: 0.5860 - val_loss: 0.9267 - val_accuracy: 0.5814 - 101ms/epoch - 8ms/step
# Epoch 43/150
# 13/13 - 0s - loss: 0.9718 - accuracy: 0.5885 - val_loss: 0.9153 - val_accuracy: 0.6113 - 99ms/epoch - 8ms/step
# Epoch 44/150
# 13/13 - 0s - loss: 1.0422 - accuracy: 0.5337 - val_loss: 1.0301 - val_accuracy: 0.5880 - 107ms/epoch - 8ms/step
# Epoch 45/150
# 13/13 - 0s - loss: 1.0562 - accuracy: 0.5395 - val_loss: 0.9410 - val_accuracy: 0.5615 - 103ms/epoch - 8ms/step
# Epoch 46/150
# 13/13 - 0s - loss: 1.0959 - accuracy: 0.5096 - val_loss: 1.2395 - val_accuracy: 0.4684 - 107ms/epoch - 8ms/step
# Epoch 47/150
# 13/13 - 0s - loss: 1.1431 - accuracy: 0.5254 - val_loss: 1.2186 - val_accuracy: 0.4884 - 111ms/epoch - 9ms/step
# Epoch 48/150
# 13/13 - 0s - loss: 1.1146 - accuracy: 0.5145 - val_loss: 1.0006 - val_accuracy: 0.5150 - 108ms/epoch - 8ms/step
# Epoch 49/150
# 13/13 - 0s - loss: 1.0294 - accuracy: 0.5345 - val_loss: 0.9359 - val_accuracy: 0.6047 - 114ms/epoch - 9ms/step
# Epoch 50/150
# 13/13 - 0s - loss: 0.9919 - accuracy: 0.5436 - val_loss: 0.9070 - val_accuracy: 0.6246 - 103ms/epoch - 8ms/step
# Epoch 51/150
# 13/13 - 0s - loss: 0.9670 - accuracy: 0.5719 - val_loss: 0.8401 - val_accuracy: 0.6213 - 113ms/epoch - 9ms/step
# Epoch 52/150
# 13/13 - 0s - loss: 0.9253 - accuracy: 0.6101 - val_loss: 1.0437 - val_accuracy: 0.6213 - 98ms/epoch - 8ms/step
# Epoch 53/150
# 13/13 - 0s - loss: 0.9517 - accuracy: 0.5902 - val_loss: 0.9169 - val_accuracy: 0.5681 - 112ms/epoch - 9ms/step
# Epoch 54/150
# 13/13 - 0s - loss: 0.9395 - accuracy: 0.6060 - val_loss: 0.9209 - val_accuracy: 0.6080 - 105ms/epoch - 8ms/step
# Epoch 55/150
# 13/13 - 0s - loss: 0.9164 - accuracy: 0.6118 - val_loss: 0.9035 - val_accuracy: 0.6246 - 108ms/epoch - 8ms/step
# Epoch 56/150
# 13/13 - 0s - loss: 0.9710 - accuracy: 0.6043 - val_loss: 0.9683 - val_accuracy: 0.6113 - 102ms/epoch - 8ms/step
# Epoch 57/150
# 13/13 - 0s - loss: 0.9697 - accuracy: 0.5802 - val_loss: 0.9710 - val_accuracy: 0.6013 - 97ms/epoch - 7ms/step
# Epoch 58/150
# 13/13 - 0s - loss: 0.9524 - accuracy: 0.5794 - val_loss: 0.7839 - val_accuracy: 0.6844 - 103ms/epoch - 8ms/step
# Epoch 59/150
# 13/13 - 0s - loss: 0.8429 - accuracy: 0.6633 - val_loss: 1.0117 - val_accuracy: 0.6146 - 108ms/epoch - 8ms/step
# Epoch 60/150
# 13/13 - 0s - loss: 0.9372 - accuracy: 0.6027 - val_loss: 0.6850 - val_accuracy: 0.7907 - 100ms/epoch - 8ms/step
# Epoch 61/150
# 13/13 - 0s - loss: 0.7750 - accuracy: 0.6866 - val_loss: 0.7430 - val_accuracy: 0.6910 - 116ms/epoch - 9ms/step
# Epoch 62/150
# 13/13 - 0s - loss: 0.7608 - accuracy: 0.6658 - val_loss: 0.6898 - val_accuracy: 0.7243 - 101ms/epoch - 8ms/step
# Epoch 63/150
# 13/13 - 0s - loss: 0.8695 - accuracy: 0.6151 - val_loss: 0.8054 - val_accuracy: 0.7143 - 97ms/epoch - 7ms/step
# Epoch 64/150
# 13/13 - 0s - loss: 0.8080 - accuracy: 0.6584 - val_loss: 0.6478 - val_accuracy: 0.7176 - 118ms/epoch - 9ms/step
# Epoch 65/150
# 13/13 - 0s - loss: 0.7017 - accuracy: 0.7307 - val_loss: 0.6054 - val_accuracy: 0.8206 - 99ms/epoch - 8ms/step
# Epoch 66/150
# 13/13 - 0s - loss: 0.6519 - accuracy: 0.7382 - val_loss: 0.6476 - val_accuracy: 0.7309 - 102ms/epoch - 8ms/step
# Epoch 67/150
# 13/13 - 0s - loss: 0.8572 - accuracy: 0.6309 - val_loss: 0.6875 - val_accuracy: 0.7409 - 103ms/epoch - 8ms/step
# Epoch 68/150
# 13/13 - 0s - loss: 0.7445 - accuracy: 0.6891 - val_loss: 0.5981 - val_accuracy: 0.7774 - 103ms/epoch - 8ms/step
# Epoch 69/150
# 13/13 - 0s - loss: 0.7225 - accuracy: 0.7024 - val_loss: 0.6083 - val_accuracy: 0.8007 - 101ms/epoch - 8ms/step
# Epoch 70/150
# 13/13 - 0s - loss: 0.7180 - accuracy: 0.7132 - val_loss: 3.2846 - val_accuracy: 0.2392 - 102ms/epoch - 8ms/step
# Epoch 71/150
# 13/13 - 0s - loss: 2.2893 - accuracy: 0.3225 - val_loss: 1.3830 - val_accuracy: 0.3555 - 117ms/epoch - 9ms/step
# Epoch 72/150
# 13/13 - 0s - loss: 1.2962 - accuracy: 0.3641 - val_loss: 1.2193 - val_accuracy: 0.5150 - 100ms/epoch - 8ms/step
# Epoch 73/150
# 13/13 - 0s - loss: 1.1435 - accuracy: 0.5121 - val_loss: 0.9441 - val_accuracy: 0.6844 - 103ms/epoch - 8ms/step
# Epoch 74/150
# 13/13 - 0s - loss: 1.0663 - accuracy: 0.5544 - val_loss: 0.9254 - val_accuracy: 0.6512 - 104ms/epoch - 8ms/step
# Epoch 75/150
# 13/13 - 0s - loss: 0.9943 - accuracy: 0.5844 - val_loss: 0.8200 - val_accuracy: 0.6711 - 102ms/epoch - 8ms/step
# Epoch 76/150
# 13/13 - 0s - loss: 0.9251 - accuracy: 0.6002 - val_loss: 1.0789 - val_accuracy: 0.6213 - 99ms/epoch - 8ms/step
# Epoch 77/150
# 13/13 - 0s - loss: 1.2920 - accuracy: 0.4381 - val_loss: 1.0394 - val_accuracy: 0.5980 - 108ms/epoch - 8ms/step
# Epoch 78/150
# 13/13 - 0s - loss: 1.0663 - accuracy: 0.5569 - val_loss: 0.8386 - val_accuracy: 0.7243 - 106ms/epoch - 8ms/step
# Epoch 79/150
# 13/13 - 0s - loss: 0.9461 - accuracy: 0.5968 - val_loss: 0.7236 - val_accuracy: 0.7475 - 103ms/epoch - 8ms/step
# Epoch 80/150
# 13/13 - 0s - loss: 0.9510 - accuracy: 0.5611 - val_loss: 0.7429 - val_accuracy: 0.7110 - 100ms/epoch - 8ms/step
# Epoch 81/150
# 13/13 - 0s - loss: 0.8535 - accuracy: 0.6442 - val_loss: 0.7743 - val_accuracy: 0.7076 - 102ms/epoch - 8ms/step
# Epoch 82/150
# 13/13 - 0s - loss: 0.8040 - accuracy: 0.6667 - val_loss: 0.5830 - val_accuracy: 0.7774 - 101ms/epoch - 8ms/step
# Epoch 83/150
# 13/13 - 0s - loss: 0.7005 - accuracy: 0.7348 - val_loss: 0.6737 - val_accuracy: 0.7442 - 100ms/epoch - 8ms/step
# Epoch 84/150
# 13/13 - 0s - loss: 0.7490 - accuracy: 0.7074 - val_loss: 0.5880 - val_accuracy: 0.7741 - 119ms/epoch - 9ms/step
# Epoch 85/150
# 13/13 - 0s - loss: 0.6429 - accuracy: 0.7448 - val_loss: 0.5694 - val_accuracy: 0.7608 - 118ms/epoch - 9ms/step
# Epoch 86/150
# 13/13 - 0s - loss: 0.5679 - accuracy: 0.7739 - val_loss: 0.5010 - val_accuracy: 0.8106 - 101ms/epoch - 8ms/step
# Epoch 87/150
# 13/13 - 0s - loss: 0.5764 - accuracy: 0.7814 - val_loss: 0.7438 - val_accuracy: 0.7342 - 106ms/epoch - 8ms/step
# Epoch 88/150
# 13/13 - 0s - loss: 0.8198 - accuracy: 0.6791 - val_loss: 0.6549 - val_accuracy: 0.7375 - 115ms/epoch - 9ms/step
# Epoch 89/150
# 13/13 - 0s - loss: 0.7463 - accuracy: 0.7016 - val_loss: 0.7043 - val_accuracy: 0.7209 - 110ms/epoch - 8ms/step
# Epoch 90/150
# 13/13 - 0s - loss: 0.6643 - accuracy: 0.7348 - val_loss: 0.6011 - val_accuracy: 0.7309 - 101ms/epoch - 8ms/step
# Epoch 91/150
# 13/13 - 0s - loss: 0.6825 - accuracy: 0.7215 - val_loss: 0.5372 - val_accuracy: 0.7674 - 100ms/epoch - 8ms/step
# Epoch 92/150
# 13/13 - 0s - loss: 0.5914 - accuracy: 0.7664 - val_loss: 0.5847 - val_accuracy: 0.7342 - 115ms/epoch - 9ms/step
# Epoch 93/150
# 13/13 - 0s - loss: 0.5451 - accuracy: 0.7930 - val_loss: 0.4753 - val_accuracy: 0.8173 - 101ms/epoch - 8ms/step
# Epoch 94/150
# 13/13 - 0s - loss: 0.5152 - accuracy: 0.7914 - val_loss: 0.4979 - val_accuracy: 0.8040 - 97ms/epoch - 7ms/step
# Epoch 95/150
# 13/13 - 0s - loss: 0.5552 - accuracy: 0.7864 - val_loss: 0.6239 - val_accuracy: 0.7508 - 103ms/epoch - 8ms/step
# Epoch 96/150
# 13/13 - 0s - loss: 0.5804 - accuracy: 0.7714 - val_loss: 0.5141 - val_accuracy: 0.7973 - 115ms/epoch - 9ms/step
# Epoch 97/150
# 13/13 - 0s - loss: 0.5043 - accuracy: 0.7997 - val_loss: 0.5532 - val_accuracy: 0.7841 - 100ms/epoch - 8ms/step
# Epoch 98/150
# 13/13 - 0s - loss: 0.5622 - accuracy: 0.7772 - val_loss: 0.5097 - val_accuracy: 0.8173 - 102ms/epoch - 8ms/step
# Epoch 99/150
# 13/13 - 0s - loss: 0.4978 - accuracy: 0.8005 - val_loss: 0.7101 - val_accuracy: 0.7575 - 99ms/epoch - 8ms/step
# Epoch 100/150
# 13/13 - 0s - loss: 0.5117 - accuracy: 0.7980 - val_loss: 0.4409 - val_accuracy: 0.8372 - 110ms/epoch - 8ms/step
# Epoch 101/150
# 13/13 - 0s - loss: 0.4851 - accuracy: 0.8005 - val_loss: 0.4836 - val_accuracy: 0.8007 - 107ms/epoch - 8ms/step
# Epoch 102/150
# 13/13 - 0s - loss: 0.4778 - accuracy: 0.7997 - val_loss: 0.5221 - val_accuracy: 0.7807 - 115ms/epoch - 9ms/step
# Epoch 103/150
# 13/13 - 0s - loss: 0.4728 - accuracy: 0.8113 - val_loss: 0.5322 - val_accuracy: 0.8106 - 100ms/epoch - 8ms/step
# Epoch 104/150
# 13/13 - 0s - loss: 0.4762 - accuracy: 0.8146 - val_loss: 0.4374 - val_accuracy: 0.8173 - 110ms/epoch - 8ms/step
# Epoch 105/150
# 13/13 - 0s - loss: 0.4608 - accuracy: 0.8163 - val_loss: 0.4329 - val_accuracy: 0.8007 - 107ms/epoch - 8ms/step
# Epoch 106/150
# 13/13 - 0s - loss: 0.4489 - accuracy: 0.8155 - val_loss: 1.1152 - val_accuracy: 0.6478 - 102ms/epoch - 8ms/step
# Epoch 107/150
# 13/13 - 0s - loss: 0.8305 - accuracy: 0.6841 - val_loss: 0.7111 - val_accuracy: 0.7243 - 109ms/epoch - 8ms/step
# Epoch 108/150
# 13/13 - 0s - loss: 0.6981 - accuracy: 0.7182 - val_loss: 0.6215 - val_accuracy: 0.7276 - 99ms/epoch - 8ms/step
# Epoch 109/150
# 13/13 - 0s - loss: 0.4775 - accuracy: 0.8071 - val_loss: 0.4392 - val_accuracy: 0.8040 - 108ms/epoch - 8ms/step
# Epoch 110/150
# 13/13 - 0s - loss: 0.4246 - accuracy: 0.8263 - val_loss: 0.9270 - val_accuracy: 0.6877 - 101ms/epoch - 8ms/step
# Epoch 111/150
# 13/13 - 0s - loss: 1.0204 - accuracy: 0.6151 - val_loss: 0.8149 - val_accuracy: 0.6844 - 112ms/epoch - 9ms/step
# Epoch 112/150
# 13/13 - 0s - loss: 0.6808 - accuracy: 0.7024 - val_loss: 0.5378 - val_accuracy: 0.7309 - 109ms/epoch - 8ms/step
# Epoch 113/150
# 13/13 - 0s - loss: 0.5564 - accuracy: 0.7531 - val_loss: 0.4591 - val_accuracy: 0.8073 - 99ms/epoch - 8ms/step
# Epoch 114/150
# 13/13 - 0s - loss: 0.4515 - accuracy: 0.8288 - val_loss: 0.8058 - val_accuracy: 0.7508 - 103ms/epoch - 8ms/step
# Epoch 115/150
# 13/13 - 0s - loss: 0.5385 - accuracy: 0.8130 - val_loss: 0.5146 - val_accuracy: 0.8140 - 106ms/epoch - 8ms/step
# Epoch 116/150
# 13/13 - 0s - loss: 0.5038 - accuracy: 0.8038 - val_loss: 0.5668 - val_accuracy: 0.7741 - 98ms/epoch - 8ms/step
# Epoch 117/150
# 13/13 - 0s - loss: 0.4175 - accuracy: 0.8437 - val_loss: 0.3793 - val_accuracy: 0.8206 - 98ms/epoch - 8ms/step
# Epoch 118/150
# 13/13 - 0s - loss: 0.4031 - accuracy: 0.8404 - val_loss: 0.5580 - val_accuracy: 0.8007 - 107ms/epoch - 8ms/step
# Epoch 119/150
# 13/13 - 0s - loss: 0.5921 - accuracy: 0.7681 - val_loss: 0.4931 - val_accuracy: 0.8073 - 95ms/epoch - 7ms/step
# Epoch 120/150
# 13/13 - 0s - loss: 0.4070 - accuracy: 0.8554 - val_loss: 0.6629 - val_accuracy: 0.7841 - 108ms/epoch - 8ms/step
# Epoch 121/150
# 13/13 - 0s - loss: 0.5383 - accuracy: 0.7789 - val_loss: 0.5687 - val_accuracy: 0.7575 - 104ms/epoch - 8ms/step
# Epoch 122/150
# 13/13 - 0s - loss: 0.5781 - accuracy: 0.7889 - val_loss: 0.5012 - val_accuracy: 0.8372 - 109ms/epoch - 8ms/step
# Epoch 123/150
# 13/13 - 0s - loss: 0.4169 - accuracy: 0.8371 - val_loss: 0.4681 - val_accuracy: 0.8439 - 108ms/epoch - 8ms/step
# Epoch 124/150
# 13/13 - 0s - loss: 0.3501 - accuracy: 0.8587 - val_loss: 0.3704 - val_accuracy: 0.8571 - 110ms/epoch - 8ms/step
# Epoch 125/150
# 13/13 - 0s - loss: 0.3465 - accuracy: 0.8520 - val_loss: 0.3616 - val_accuracy: 0.8638 - 101ms/epoch - 8ms/step
# Epoch 126/150
# 13/13 - 0s - loss: 0.3042 - accuracy: 0.8728 - val_loss: 0.3541 - val_accuracy: 0.8405 - 98ms/epoch - 8ms/step
# Epoch 127/150
# 13/13 - 0s - loss: 0.3380 - accuracy: 0.8678 - val_loss: 0.7160 - val_accuracy: 0.7442 - 107ms/epoch - 8ms/step
# Epoch 128/150
# 13/13 - 0s - loss: 0.7817 - accuracy: 0.6841 - val_loss: 0.5199 - val_accuracy: 0.8339 - 106ms/epoch - 8ms/step
# Epoch 129/150
# 13/13 - 0s - loss: 0.4385 - accuracy: 0.8371 - val_loss: 0.3617 - val_accuracy: 0.8538 - 107ms/epoch - 8ms/step
# Epoch 130/150
# 13/13 - 0s - loss: 0.3543 - accuracy: 0.8628 - val_loss: 0.4227 - val_accuracy: 0.8040 - 96ms/epoch - 7ms/step
# Epoch 131/150
# 13/13 - 0s - loss: 0.3118 - accuracy: 0.8795 - val_loss: 0.3626 - val_accuracy: 0.8439 - 98ms/epoch - 8ms/step
# Epoch 132/150
# 13/13 - 0s - loss: 0.2720 - accuracy: 0.9061 - val_loss: 0.3198 - val_accuracy: 0.8738 - 102ms/epoch - 8ms/step
# Epoch 133/150
# 13/13 - 0s - loss: 0.2850 - accuracy: 0.8911 - val_loss: 0.6589 - val_accuracy: 0.7409 - 118ms/epoch - 9ms/step
# Epoch 134/150
# 13/13 - 0s - loss: 0.4316 - accuracy: 0.8271 - val_loss: 0.4080 - val_accuracy: 0.8605 - 105ms/epoch - 8ms/step
# Epoch 135/150
# 13/13 - 0s - loss: 0.3051 - accuracy: 0.8712 - val_loss: 0.4338 - val_accuracy: 0.8372 - 107ms/epoch - 8ms/step
# Epoch 136/150
# 13/13 - 0s - loss: 0.2967 - accuracy: 0.8786 - val_loss: 0.4668 - val_accuracy: 0.8239 - 105ms/epoch - 8ms/step
# Epoch 137/150
# 13/13 - 0s - loss: 0.4296 - accuracy: 0.8412 - val_loss: 0.3694 - val_accuracy: 0.8339 - 108ms/epoch - 8ms/step
# Epoch 138/150
# 13/13 - 0s - loss: 0.3094 - accuracy: 0.8811 - val_loss: 0.4178 - val_accuracy: 0.8272 - 104ms/epoch - 8ms/step
# Epoch 139/150
# 13/13 - 0s - loss: 0.2801 - accuracy: 0.8836 - val_loss: 0.4189 - val_accuracy: 0.8140 - 108ms/epoch - 8ms/step
# Epoch 140/150
# 13/13 - 0s - loss: 0.2659 - accuracy: 0.8928 - val_loss: 0.8548 - val_accuracy: 0.7708 - 109ms/epoch - 8ms/step
# Epoch 141/150
# 13/13 - 0s - loss: 0.4054 - accuracy: 0.8479 - val_loss: 0.3962 - val_accuracy: 0.8505 - 100ms/epoch - 8ms/step
# Epoch 142/150
# 13/13 - 0s - loss: 0.2663 - accuracy: 0.8978 - val_loss: 0.3348 - val_accuracy: 0.8671 - 102ms/epoch - 8ms/step
# Epoch 143/150
# 13/13 - 0s - loss: 0.2835 - accuracy: 0.8861 - val_loss: 0.5327 - val_accuracy: 0.8106 - 101ms/epoch - 8ms/step
# Epoch 144/150
# 13/13 - 0s - loss: 0.6241 - accuracy: 0.7781 - val_loss: 0.5103 - val_accuracy: 0.7741 - 96ms/epoch - 7ms/step
# Epoch 145/150
# 13/13 - 0s - loss: 0.5999 - accuracy: 0.7689 - val_loss: 0.4298 - val_accuracy: 0.8439 - 96ms/epoch - 7ms/step
# Epoch 146/150
# 13/13 - 0s - loss: 0.3175 - accuracy: 0.8778 - val_loss: 0.3513 - val_accuracy: 0.8704 - 112ms/epoch - 9ms/step
# Epoch 147/150
# 13/13 - 0s - loss: 0.2581 - accuracy: 0.8953 - val_loss: 0.4013 - val_accuracy: 0.8671 - 109ms/epoch - 8ms/step
# Epoch 148/150
# 13/13 - 0s - loss: 0.2425 - accuracy: 0.9027 - val_loss: 0.4475 - val_accuracy: 0.8571 - 112ms/epoch - 9ms/step
# Epoch 149/150
# 13/13 - 0s - loss: 0.4019 - accuracy: 0.8520 - val_loss: 0.5022 - val_accuracy: 0.8306 - 102ms/epoch - 8ms/step
# Epoch 150/150
# 13/13 - 0s - loss: 0.3963 - accuracy: 0.8512 - val_loss: 0.4599 - val_accuracy: 0.8040 - 101ms/epoch - 8ms/step

# %% [markdown]
# ## 評估訓練結果

# %%
def show_train_history(train_history, train, validation):

    plt.plot(train_history.history[train])

    plt.plot(train_history.history[validation])

    plt.title('Train History')

    plt.ylabel('train')

    plt.xlabel('Epoch')

    plt.legend(['train', 'validation'], loc='upper left')

    plt.show()
    

show_train_history(train_history, 'accuracy', 'val_accuracy')
show_train_history(train_history, 'loss', 'val_loss')

# %% [markdown]
# ## 使用未參與訓練的測試資料測試，模型準確率

# %%
scores = model.evaluate(X_test,y_test,verbose=0)

print('Accuracy = ', scores[1])
# Out:
# Accuracy =  0.811170220375061

# %% [markdown]
# ## 評估訓練結果

# %%
y_pred = np.argmax(model.predict(X_test), axis=-1)
y_true = np.argmax(y_test, axis=-1)
confusion_matrix = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10,7))
sns.heatmap(confusion_matrix, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()
# Out:
# 12/12 [==============================] - 0s 2ms/step
